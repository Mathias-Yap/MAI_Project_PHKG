# %%
from collections import defaultdict
from itertools import combinations
from typing import Dict, List, Tuple
from OntologyDesc import OntologyDesc
from Enumerator import Enumerator
from OntologyChainEnumerator import OntologyChainEnumerator
from OntologyStarEnumerator import OntologyStarEnumerator 

Ontology = OntologyDesc()
star_enumerator = OntologyStarEnumerator(Ontology)
chain_enumerator = OntologyChainEnumerator(Ontology)

# %%
star_queries = star_enumerator.enumerate_all()
chain_queries = chain_enumerator.enumerate_all()

# %%
chain_queries[4]
# Out:
# [[('Substance', 'hasActiveIngredient⁻¹', 'Drug'),
#   ('Drug', 'hasActiveIngredient', 'Substance'),
#   ('Substance', 'hasActiveIngredient⁻¹', 'Drug'),
#   ('Drug', 'hasActiveIngredient', 'Substance')],
#  [('Substance', 'hasActiveIngredient⁻¹', 'Drug'),
#   ('Drug', 'hasActiveIngredient', 'Substance'),
#   ('Substance', 'hasActiveIngredient⁻¹', 'Drug'),
#   ('Drug', 'hasCode', 'Code')],
#  [('Substance', 'hasActiveIngredient⁻¹', 'Drug'),
#   ('Drug', 'hasActiveIngredient', 'Substance'),
#   ('Substance', 'hasActiveIngredient⁻¹', 'Drug'),
#   ('Drug', 'hasDrug⁻¹', 'DrugPrescription')],
#  [('Substance', 'hasActiveIngredient⁻¹', 'Drug'),
#   ('Drug', 'hasCode', 'Code'),
#   ('Code', 'hasCodingSystemAndVersion', 'CodingSystem'),
#   ('CodingSystem', 'hasCodingSystemAndVersion⁻¹', 'Diagnosis')],
#  [('Substance', 'hasActiveIngredient⁻¹', 'Drug'),
#   ('Drug', 'hasCode', 'Code'),
#   ('Code', 'hasCodingSystemAndVersion', 'CodingSystem'),
#   ('CodingSystem', 'hasCodingSystemAndVersion⁻¹', 'MedicalProcedure')],
#  [('Substance', 'hasActiveIngredient⁻¹', 'Drug'),
#   ('Drug', 'hasCode', 'Code'),
#   ('Code', 'hasCodingSystemAndVersion', 'CodingSystem'),
#   ('CodingSystem', 'hasCodingSystemAndVersion⁻¹', 'Code')],
#  [('Substance', 'hasActiveIngredient⁻¹', 'Drug'),
#   ('Drug', 'hasCode', 'Code'),
#   ('Code', 'hasCode⁻¹', 'LabResult'),
#   ('LabResult', 'hasCode', 'Code')],
#  [('Substance', 'hasActiveIngredient⁻¹', 'Drug'),
#   ('Drug', 'hasCode', 'Code'),
#   ('Code', 'hasCode⁻¹', 'LabResult'),
#   ('LabResult', 'hasLabTest⁻¹', 'LabTestEvent')],
#  [('Substance', 'hasActiveIngredient⁻¹', 'Drug'),
#   ('Drug', 'hasCode', 'Code'),
#   ('Code', 'hasCode⁻¹', 'Drug'),
#   ('Drug', 'hasActiveIngredient', 'Substance')],
#  [('Substance', 'hasActiveIngredient⁻¹', 'Drug'),
#   ('Drug', 'hasCode', 'Code'),
#   ('Code', 'hasCode⁻¹', 'Drug'),
#   ('Drug', 'hasCode', 'Code')],
#  [('Substance', 'hasActiveIngredient⁻¹', 'Drug'),
#   ('Drug', 'hasCode', 'Code'),
#   ('Code', 'hasCode⁻¹', 'Drug'),
#   ('Drug', 'hasDrug⁻¹', 'DrugPrescription')],
#  [('Substance', 'hasActiveIngredient⁻¹', 'Drug'),
#   ('Drug', 'hasCode', 'Code'),
#   ('Code', 'hasCode⁻¹', 'MedicalProcedure'),
#   ('MedicalProcedure', 'hasCode', 'Code')],
#  [('Substance', 'hasActiveIngredient⁻¹', 'Drug'),
#   ('Drug', 'hasCode', 'Code'),
#   ('Code', 'hasCode⁻¹', 'MedicalProcedure'),
#   ('MedicalProcedure', 'hasCodingSystemAndVersion', 'CodingSystem')],
#  [('Substance', 'hasActiveIngredient⁻¹', 'Drug'),
#   ('Drug', 'hasCode', 'Code'),
#   ('Code', 'hasCode⁻¹', 'MedicalProcedure'),
#   ('MedicalProcedure', 'hasSubjectPseudIdentifier', 'Patient')],
#  [('Substance', 'hasActiveIngredient⁻¹', 'Drug'),
#   ('Drug', 'hasCode', 'Code'),
#   ('Code', 'hasCode⁻¹', 'Diagnosis'),
#   ('Diagnosis', 'hasCode', 'Code')],
#  [('Substance', 'hasActiveIngredient⁻¹', 'Drug'),
#   ('Drug', 'hasCode', 'Code'),
#   ('Code', 'hasCode⁻¹', 'Diagnosis'),
#   ('Diagnosis', 'hasCodingSystemAndVersion', 'CodingSystem')],
#  [('Substance', 'hasActiveIngredient⁻¹', 'Drug'),
#   ('Drug', 'hasCode', 'Code'),
#   ('Code', 'hasCode⁻¹', 'Diagnosis'),
#   ('Diagnosis', 'hasSubjectPseudIdentifier', 'Patient')],
#  [('Substance', 'hasActiveIngredient⁻¹', 'Drug'),
#   ('Drug', 'hasDrug⁻¹', 'DrugPrescription'),
#   ('DrugPrescription', 'hasDrug', 'Drug'),
#   ('Drug', 'hasActiveIngredient', 'Substance')],
#  [('Substance', 'hasActiveIngredient⁻¹', 'Drug'),
#   ('Drug', 'hasDrug⁻¹', 'DrugPrescription'),
#   ('DrugPrescription', 'hasDrug', 'Drug'),
#   ('Drug', 'hasCode', 'Code')],
#  [('Substance', 'hasActiveIngredient⁻¹', 'Drug'),
#   ('Drug', 'hasDrug⁻¹', 'DrugPrescription'),
#   ('DrugPrescription', 'hasDrug', 'Drug'),
#   ('Drug', 'hasDrug⁻¹', 'DrugPrescription')],
#  [('Substance', 'hasActiveIngredient⁻¹', 'Drug'),
#   ('Drug', 'hasDrug⁻¹', 'DrugPrescription'),
#   ('DrugPrescription', 'hasSubjectPseudIdentifier', 'Patient'),
#   ('Patient', 'hasSubjectPseudIdentifier⁻¹', 'LabTestEvent')],
#  [('Substance', 'hasActiveIngredient⁻¹', 'Drug'),
#   ('Drug', 'hasDrug⁻¹', 'DrugPrescription'),
#   ('DrugPrescription', 'hasSubjectPseudIdentifier', 'Patient'),
#   ('Patient', 'hasSubjectPseudIdentifier⁻¹', 'MedicalProcedure')],
#  [('Substance', 'hasActiveIngredient⁻¹', 'Drug'),
#   ('Drug', 'hasDrug⁻¹', 'DrugPrescription'),
#   ('DrugPrescription', 'hasSubjectPseudIdentifier', 'Patient'),
#   ('Patient', 'hasSubjectPseudIdentifier⁻¹', 'Diagnosis')],
#  [('Substance', 'hasActiveIngredient⁻¹', 'Drug'),
#   ('Drug', 'hasDrug⁻¹', 'DrugPrescription'),
#   ('DrugPrescription', 'hasSubjectPseudIdentifier', 'Patient'),
#   ('Patient', 'hasSubjectPseudIdentifier⁻¹', 'DrugPrescription')],
#  [('Diagnosis', 'hasCode', 'Code'),
#   ('Code', 'hasCodingSystemAndVersion', 'CodingSystem'),
#   ('CodingSystem', 'hasCodingSystemAndVersion⁻¹', 'Diagnosis'),
#   ('Diagnosis', 'hasCode', 'Code')],
#  [('Diagnosis', 'hasCode', 'Code'),
#   ('Code', 'hasCodingSystemAndVersion', 'CodingSystem'),
#   ('CodingSystem', 'hasCodingSystemAndVersion⁻¹', 'Diagnosis'),
#   ('Diagnosis', 'hasCodingSystemAndVersion', 'CodingSystem')],
#  [('Diagnosis', 'hasCode', 'Code'),
#   ('Code', 'hasCodingSystemAndVersion', 'CodingSystem'),
#   ('CodingSystem', 'hasCodingSystemAndVersion⁻¹', 'Diagnosis'),
#   ('Diagnosis', 'hasSubjectPseudIdentifier', 'Patient')],
#  [('Diagnosis', 'hasCode', 'Code'),
#   ('Code', 'hasCodingSystemAndVersion', 'CodingSystem'),
#   ('CodingSystem', 'hasCodingSystemAndVersion⁻¹', 'MedicalProcedure'),
#   ('MedicalProcedure', 'hasCode', 'Code')],
#  [('Diagnosis', 'hasCode', 'Code'),
#   ('Code', 'hasCodingSystemAndVersion', 'CodingSystem'),
#   ('CodingSystem', 'hasCodingSystemAndVersion⁻¹', 'MedicalProcedure'),
#   ('MedicalProcedure', 'hasCodingSystemAndVersion', 'CodingSystem')],
#  [('Diagnosis', 'hasCode', 'Code'),
#   ('Code', 'hasCodingSystemAndVersion', 'CodingSystem'),
#   ('CodingSystem', 'hasCodingSystemAndVersion⁻¹', 'MedicalProcedure'),
#   ('MedicalProcedure', 'hasSubjectPseudIdentifier', 'Patient')],
#  [('Diagnosis', 'hasCode', 'Code'),
#   ('Code', 'hasCodingSystemAndVersion', 'CodingSystem'),
#   ('CodingSystem', 'hasCodingSystemAndVersion⁻¹', 'Code'),
#   ('Code', 'hasCodingSystemAndVersion', 'CodingSystem')],
#  [('Diagnosis', 'hasCode', 'Code'),
#   ('Code', 'hasCodingSystemAndVersion', 'CodingSystem'),
#   ('CodingSystem', 'hasCodingSystemAndVersion⁻¹', 'Code'),
#   ('Code', 'hasCode⁻¹', 'LabResult')],
#  [('Diagnosis', 'hasCode', 'Code'),
#   ('Code', 'hasCodingSystemAndVersion', 'CodingSystem'),
#   ('CodingSystem', 'hasCodingSystemAndVersion⁻¹', 'Code'),
#   ('Code', 'hasCode⁻¹', 'Drug')],
#  [('Diagnosis', 'hasCode', 'Code'),
#   ('Code', 'hasCodingSystemAndVersion', 'CodingSystem'),
#   ('CodingSystem', 'hasCodingSystemAndVersion⁻¹', 'Code'),
#   ('Code', 'hasCode⁻¹', 'MedicalProcedure')],
#  [('Diagnosis', 'hasCode', 'Code'),
#   ('Code', 'hasCodingSystemAndVersion', 'CodingSystem'),
#   ('CodingSystem', 'hasCodingSystemAndVersion⁻¹', 'Code'),
#   ('Code', 'hasCode⁻¹', 'Diagnosis')],
#  [('Diagnosis', 'hasCode', 'Code'),
#   ('Code', 'hasCode⁻¹', 'LabResult'),
#   ('LabResult', 'hasCode', 'Code'),
#   ('Code', 'hasCodingSystemAndVersion', 'CodingSystem')],
#  [('Diagnosis', 'hasCode', 'Code'),
#   ('Code', 'hasCode⁻¹', 'LabResult'),
#   ('LabResult', 'hasCode', 'Code'),
#   ('Code', 'hasCode⁻¹', 'LabResult')],
#  [('Diagnosis', 'hasCode', 'Code'),
#   ('Code', 'hasCode⁻¹', 'LabResult'),
#   ('LabResult', 'hasCode', 'Code'),
#   ('Code', 'hasCode⁻¹', 'Drug')],
#  [('Diagnosis', 'hasCode', 'Code'),
#   ('Code', 'hasCode⁻¹', 'LabResult'),
#   ('LabResult', 'hasCode', 'Code'),
#   ('Code', 'hasCode⁻¹', 'MedicalProcedure')],
#  [('Diagnosis', 'hasCode', 'Code'),
#   ('Code', 'hasCode⁻¹', 'LabResult'),
#   ('LabResult', 'hasCode', 'Code'),
#   ('Code', 'hasCode⁻¹', 'Diagnosis')],
#  [('Diagnosis', 'hasCode', 'Code'),
#   ('Code', 'hasCode⁻¹', 'LabResult'),
#   ('LabResult', 'hasLabTest⁻¹', 'LabTestEvent'),
#   ('LabTestEvent', 'hasLabTest', 'LabResult')],
#  [('Diagnosis', 'hasCode', 'Code'),
#   ('Code', 'hasCode⁻¹', 'LabResult'),
#   ('LabResult', 'hasLabTest⁻¹', 'LabTestEvent'),
#   ('LabTestEvent', 'hasSubjectPseudIdentifier', 'Patient')],
#  [('Diagnosis', 'hasCode', 'Code'),
#   ('Code', 'hasCode⁻¹', 'Drug'),
#   ('Drug', 'hasActiveIngredient', 'Substance'),
#   ('Substance', 'hasActiveIngredient⁻¹', 'Drug')],
#  [('Diagnosis', 'hasCode', 'Code'),
#   ('Code', 'hasCode⁻¹', 'Drug'),
#   ('Drug', 'hasCode', 'Code'),
#   ('Code', 'hasCodingSystemAndVersion', 'CodingSystem')],
#  [('Diagnosis', 'hasCode', 'Code'),
#   ('Code', 'hasCode⁻¹', 'Drug'),
#   ('Drug', 'hasCode', 'Code'),
#   ('Code', 'hasCode⁻¹', 'LabResult')],
#  [('Diagnosis', 'hasCode', 'Code'),
#   ('Code', 'hasCode⁻¹', 'Drug'),
#   ('Drug', 'hasCode', 'Code'),
#   ('Code', 'hasCode⁻¹', 'Drug')],
#  [('Diagnosis', 'hasCode', 'Code'),
#   ('Code', 'hasCode⁻¹', 'Drug'),
#   ('Drug', 'hasCode', 'Code'),
#   ('Code', 'hasCode⁻¹', 'MedicalProcedure')],
#  [('Diagnosis', 'hasCode', 'Code'),
#   ('Code', 'hasCode⁻¹', 'Drug'),
#   ('Drug', 'hasCode', 'Code'),
#   ('Code', 'hasCode⁻¹', 'Diagnosis')],
#  [('Diagnosis', 'hasCode', 'Code'),
#   ('Code', 'hasCode⁻¹', 'Drug'),
#   ('Drug', 'hasDrug⁻¹', 'DrugPrescription'),
#   ('DrugPrescription', 'hasDrug', 'Drug')],
#  [('Diagnosis', 'hasCode', 'Code'),
#   ('Code', 'hasCode⁻¹', 'Drug'),
#   ('Drug', 'hasDrug⁻¹', 'DrugPrescription'),
#   ('DrugPrescription', 'hasSubjectPseudIdentifier', 'Patient')],
#  [('Diagnosis', 'hasCode', 'Code'),
#   ('Code', 'hasCode⁻¹', 'MedicalProcedure'),
#   ('MedicalProcedure', 'hasCode', 'Code'),
#   ('Code', 'hasCodingSystemAndVersion', 'CodingSystem')],
#  [('Diagnosis', 'hasCode', 'Code'),
#   ('Code', 'hasCode⁻¹', 'MedicalProcedure'),
#   ('MedicalProcedure', 'hasCode', 'Code'),
#   ('Code', 'hasCode⁻¹', 'LabResult')],
#  [('Diagnosis', 'hasCode', 'Code'),
#   ('Code', 'hasCode⁻¹', 'MedicalProcedure'),
#   ('MedicalProcedure', 'hasCode', 'Code'),
#   ('Code', 'hasCode⁻¹', 'Drug')],
#  [('Diagnosis', 'hasCode', 'Code'),
#   ('Code', 'hasCode⁻¹', 'MedicalProcedure'),
#   ('MedicalProcedure', 'hasCode', 'Code'),
#   ('Code', 'hasCode⁻¹', 'MedicalProcedure')],
#  [('Diagnosis', 'hasCode', 'Code'),
#   ('Code', 'hasCode⁻¹', 'MedicalProcedure'),
#   ('MedicalProcedure', 'hasCode', 'Code'),
#   ('Code', 'hasCode⁻¹', 'Diagnosis')],
#  [('Diagnosis', 'hasCode', 'Code'),
#   ('Code', 'hasCode⁻¹', 'MedicalProcedure'),
#   ('MedicalProcedure', 'hasCodingSystemAndVersion', 'CodingSystem'),
#   ('CodingSystem', 'hasCodingSystemAndVersion⁻¹', 'Diagnosis')],
#  [('Diagnosis', 'hasCode', 'Code'),
#   ('Code', 'hasCode⁻¹', 'MedicalProcedure'),
#   ('MedicalProcedure', 'hasCodingSystemAndVersion', 'CodingSystem'),
#   ('CodingSystem', 'hasCodingSystemAndVersion⁻¹', 'MedicalProcedure')],
#  [('Diagnosis', 'hasCode', 'Code'),
#   ('Code', 'hasCode⁻¹', 'MedicalProcedure'),
#   ('MedicalProcedure', 'hasCodingSystemAndVersion', 'CodingSystem'),
#   ('CodingSystem', 'hasCodingSystemAndVersion⁻¹', 'Code')],
#  [('Diagnosis', 'hasCode', 'Code'),
#   ('Code', 'hasCode⁻¹', 'MedicalProcedure'),
#   ('MedicalProcedure', 'hasSubjectPseudIdentifier', 'Patient'),
#   ('Patient', 'hasSubjectPseudIdentifier⁻¹', 'LabTestEvent')],
#  [('Diagnosis', 'hasCode', 'Code'),
#   ('Code', 'hasCode⁻¹', 'MedicalProcedure'),
#   ('MedicalProcedure', 'hasSubjectPseudIdentifier', 'Patient'),
#   ('Patient', 'hasSubjectPseudIdentifier⁻¹', 'MedicalProcedure')],
#  [('Diagnosis', 'hasCode', 'Code'),
#   ('Code', 'hasCode⁻¹', 'MedicalProcedure'),
#   ('MedicalProcedure', 'hasSubjectPseudIdentifier', 'Patient'),
#   ('Patient', 'hasSubjectPseudIdentifier⁻¹', 'Diagnosis')],
#  [('Diagnosis', 'hasCode', 'Code'),
#   ('Code', 'hasCode⁻¹', 'MedicalProcedure'),
#   ('MedicalProcedure', 'hasSubjectPseudIdentifier', 'Patient'),
#   ('Patient', 'hasSubjectPseudIdentifier⁻¹', 'DrugPrescription')],
#  [('Diagnosis', 'hasCode', 'Code'),
#   ('Code', 'hasCode⁻¹', 'Diagnosis'),
#   ('Diagnosis', 'hasCode', 'Code'),
#   ('Code', 'hasCodingSystemAndVersion', 'CodingSystem')],
#  [('Diagnosis', 'hasCode', 'Code'),
#   ('Code', 'hasCode⁻¹', 'Diagnosis'),
#   ('Diagnosis', 'hasCode', 'Code'),
#   ('Code', 'hasCode⁻¹', 'LabResult')],
#  [('Diagnosis', 'hasCode', 'Code'),
#   ('Code', 'hasCode⁻¹', 'Diagnosis'),
#   ('Diagnosis', 'hasCode', 'Code'),
#   ('Code', 'hasCode⁻¹', 'Drug')],
#  [('Diagnosis', 'hasCode', 'Code'),
#   ('Code', 'hasCode⁻¹', 'Diagnosis'),
#   ('Diagnosis', 'hasCode', 'Code'),
#   ('Code', 'hasCode⁻¹', 'MedicalProcedure')],
#  [('Diagnosis', 'hasCode', 'Code'),
#   ('Code', 'hasCode⁻¹', 'Diagnosis'),
#   ('Diagnosis', 'hasCode', 'Code'),
#   ('Code', 'hasCode⁻¹', 'Diagnosis')],
#  [('Diagnosis', 'hasCode', 'Code'),
#   ('Code', 'hasCode⁻¹', 'Diagnosis'),
#   ('Diagnosis', 'hasCodingSystemAndVersion', 'CodingSystem'),
#   ('CodingSystem', 'hasCodingSystemAndVersion⁻¹', 'Diagnosis')],
#  [('Diagnosis', 'hasCode', 'Code'),
#   ('Code', 'hasCode⁻¹', 'Diagnosis'),
#   ('Diagnosis', 'hasCodingSystemAndVersion', 'CodingSystem'),
#   ('CodingSystem', 'hasCodingSystemAndVersion⁻¹', 'MedicalProcedure')],
#  [('Diagnosis', 'hasCode', 'Code'),
#   ('Code', 'hasCode⁻¹', 'Diagnosis'),
#   ('Diagnosis', 'hasCodingSystemAndVersion', 'CodingSystem'),
#   ('CodingSystem', 'hasCodingSystemAndVersion⁻¹', 'Code')],
#  [('Diagnosis', 'hasCode', 'Code'),
#   ('Code', 'hasCode⁻¹', 'Diagnosis'),
#   ('Diagnosis', 'hasSubjectPseudIdentifier', 'Patient'),
#   ('Patient', 'hasSubjectPseudIdentifier⁻¹', 'LabTestEvent')],
#  [('Diagnosis', 'hasCode', 'Code'),
#   ('Code', 'hasCode⁻¹', 'Diagnosis'),
#   ('Diagnosis', 'hasSubjectPseudIdentifier', 'Patient'),
#   ('Patient', 'hasSubjectPseudIdentifier⁻¹', 'MedicalProcedure')],
#  [('Diagnosis', 'hasCode', 'Code'),
#   ('Code', 'hasCode⁻¹', 'Diagnosis'),
#   ('Diagnosis', 'hasSubjectPseudIdentifier', 'Patient'),
#   ('Patient', 'hasSubjectPseudIdentifier⁻¹', 'Diagnosis')],
#  [('Diagnosis', 'hasCode', 'Code'),
#   ('Code', 'hasCode⁻¹', 'Diagnosis'),
#   ('Diagnosis', 'hasSubjectPseudIdentifier', 'Patient'),
#   ('Patient', 'hasSubjectPseudIdentifier⁻¹', 'DrugPrescription')],
#  [('Diagnosis', 'hasCodingSystemAndVersion', 'CodingSystem'),
#   ('CodingSystem', 'hasCodingSystemAndVersion⁻¹', 'Diagnosis'),
#   ('Diagnosis', 'hasCode', 'Code'),
#   ('Code', 'hasCodingSystemAndVersion', 'CodingSystem')],
#  [('Diagnosis', 'hasCodingSystemAndVersion', 'CodingSystem'),
#   ('CodingSystem', 'hasCodingSystemAndVersion⁻¹', 'Diagnosis'),
#   ('Diagnosis', 'hasCode', 'Code'),
#   ('Code', 'hasCode⁻¹', 'LabResult')],
#  [('Diagnosis', 'hasCodingSystemAndVersion', 'CodingSystem'),
#   ('CodingSystem', 'hasCodingSystemAndVersion⁻¹', 'Diagnosis'),
#   ('Diagnosis', 'hasCode', 'Code'),
#   ('Code', 'hasCode⁻¹', 'Drug')],
#  [('Diagnosis', 'hasCodingSystemAndVersion', 'CodingSystem'),
#   ('CodingSystem', 'hasCodingSystemAndVersion⁻¹', 'Diagnosis'),
#   ('Diagnosis', 'hasCode', 'Code'),
#   ('Code', 'hasCode⁻¹', 'MedicalProcedure')],
#  [('Diagnosis', 'hasCodingSystemAndVersion', 'CodingSystem'),
#   ('CodingSystem', 'hasCodingSystemAndVersion⁻¹', 'Diagnosis'),
#   ('Diagnosis', 'hasCode', 'Code'),
#   ('Code', 'hasCode⁻¹', 'Diagnosis')],
#  [('Diagnosis', 'hasCodingSystemAndVersion', 'CodingSystem'),
#   ('CodingSystem', 'hasCodingSystemAndVersion⁻¹', 'Diagnosis'),
#   ('Diagnosis', 'hasCodingSystemAndVersion', 'CodingSystem'),
#   ('CodingSystem', 'hasCodingSystemAndVersion⁻¹', 'Diagnosis')],
#  [('Diagnosis', 'hasCodingSystemAndVersion', 'CodingSystem'),
#   ('CodingSystem', 'hasCodingSystemAndVersion⁻¹', 'Diagnosis'),
#   ('Diagnosis', 'hasCodingSystemAndVersion', 'CodingSystem'),
#   ('CodingSystem', 'hasCodingSystemAndVersion⁻¹', 'MedicalProcedure')],
#  [('Diagnosis', 'hasCodingSystemAndVersion', 'CodingSystem'),
#   ('CodingSystem', 'hasCodingSystemAndVersion⁻¹', 'Diagnosis'),
#   ('Diagnosis', 'hasCodingSystemAndVersion', 'CodingSystem'),
#   ('CodingSystem', 'hasCodingSystemAndVersion⁻¹', 'Code')],
#  [('Diagnosis', 'hasCodingSystemAndVersion', 'CodingSystem'),
#   ('CodingSystem', 'hasCodingSystemAndVersion⁻¹', 'Diagnosis'),
#   ('Diagnosis', 'hasSubjectPseudIdentifier', 'Patient'),
#   ('Patient', 'hasSubjectPseudIdentifier⁻¹', 'LabTestEvent')],
#  [('Diagnosis', 'hasCodingSystemAndVersion', 'CodingSystem'),
#   ('CodingSystem', 'hasCodingSystemAndVersion⁻¹', 'Diagnosis'),
#   ('Diagnosis', 'hasSubjectPseudIdentifier', 'Patient'),
#   ('Patient', 'hasSubjectPseudIdentifier⁻¹', 'MedicalProcedure')],
#  [('Diagnosis', 'hasCodingSystemAndVersion', 'CodingSystem'),
#   ('CodingSystem', 'hasCodingSystemAndVersion⁻¹', 'Diagnosis'),
#   ('Diagnosis', 'hasSubjectPseudIdentifier', 'Patient'),
#   ('Patient', 'hasSubjectPseudIdentifier⁻¹', 'Diagnosis')],
#  [('Diagnosis', 'hasCodingSystemAndVersion', 'CodingSystem'),
#   ('CodingSystem', 'hasCodingSystemAndVersion⁻¹', 'Diagnosis'),
#   ('Diagnosis', 'hasSubjectPseudIdentifier', 'Patient'),
#   ('Patient', 'hasSubjectPseudIdentifier⁻¹', 'DrugPrescription')],
#  [('Diagnosis', 'hasCodingSystemAndVersion', 'CodingSystem'),
#   ('CodingSystem', 'hasCodingSystemAndVersion⁻¹', 'MedicalProcedure'),
#   ('MedicalProcedure', 'hasCode', 'Code'),
#   ('Code', 'hasCodingSystemAndVersion', 'CodingSystem')],
#  [('Diagnosis', 'hasCodingSystemAndVersion', 'CodingSystem'),
#   ('CodingSystem', 'hasCodingSystemAndVersion⁻¹', 'MedicalProcedure'),
#   ('MedicalProcedure', 'hasCode', 'Code'),
#   ('Code', 'hasCode⁻¹', 'LabResult')],
#  [('Diagnosis', 'hasCodingSystemAndVersion', 'CodingSystem'),
#   ('CodingSystem', 'hasCodingSystemAndVersion⁻¹', 'MedicalProcedure'),
#   ('MedicalProcedure', 'hasCode', 'Code'),
#   ('Code', 'hasCode⁻¹', 'Drug')],
#  [('Diagnosis', 'hasCodingSystemAndVersion', 'CodingSystem'),
#   ('CodingSystem', 'hasCodingSystemAndVersion⁻¹', 'MedicalProcedure'),
#   ('MedicalProcedure', 'hasCode', 'Code'),
#   ('Code', 'hasCode⁻¹', 'MedicalProcedure')],
#  [('Diagnosis', 'hasCodingSystemAndVersion', 'CodingSystem'),
#   ('CodingSystem', 'hasCodingSystemAndVersion⁻¹', 'MedicalProcedure'),
#   ('MedicalProcedure', 'hasCode', 'Code'),
#   ('Code', 'hasCode⁻¹', 'Diagnosis')],
#  [('Diagnosis', 'hasCodingSystemAndVersion', 'CodingSystem'),
#   ('CodingSystem', 'hasCodingSystemAndVersion⁻¹', 'MedicalProcedure'),
#   ('MedicalProcedure', 'hasCodingSystemAndVersion', 'CodingSystem'),
#   ('CodingSystem', 'hasCodingSystemAndVersion⁻¹', 'Diagnosis')],
#  [('Diagnosis', 'hasCodingSystemAndVersion', 'CodingSystem'),
#   ('CodingSystem', 'hasCodingSystemAndVersion⁻¹', 'MedicalProcedure'),
#   ('MedicalProcedure', 'hasCodingSystemAndVersion', 'CodingSystem'),
#   ('CodingSystem', 'hasCodingSystemAndVersion⁻¹', 'MedicalProcedure')],
#  [('Diagnosis', 'hasCodingSystemAndVersion', 'CodingSystem'),
#   ('CodingSystem', 'hasCodingSystemAndVersion⁻¹', 'MedicalProcedure'),
#   ('MedicalProcedure', 'hasCodingSystemAndVersion', 'CodingSystem'),
#   ('CodingSystem', 'hasCodingSystemAndVersion⁻¹', 'Code')],
#  [('Diagnosis', 'hasCodingSystemAndVersion', 'CodingSystem'),
#   ('CodingSystem', 'hasCodingSystemAndVersion⁻¹', 'MedicalProcedure'),
#   ('MedicalProcedure', 'hasSubjectPseudIdentifier', 'Patient'),
#   ('Patient', 'hasSubjectPseudIdentifier⁻¹', 'LabTestEvent')],
#  [('Diagnosis', 'hasCodingSystemAndVersion', 'CodingSystem'),
#   ('CodingSystem', 'hasCodingSystemAndVersion⁻¹', 'MedicalProcedure'),
#   ('MedicalProcedure', 'hasSubjectPseudIdentifier', 'Patient'),
#   ('Patient', 'hasSubjectPseudIdentifier⁻¹', 'MedicalProcedure')],
#  [('Diagnosis', 'hasCodingSystemAndVersion', 'CodingSystem'),
#   ('CodingSystem', 'hasCodingSystemAndVersion⁻¹', 'MedicalProcedure'),
#   ('MedicalProcedure', 'hasSubjectPseudIdentifier', 'Patient'),
#   ('Patient', 'hasSubjectPseudIdentifier⁻¹', 'Diagnosis')],
#  [('Diagnosis', 'hasCodingSystemAndVersion', 'CodingSystem'),
#   ('CodingSystem', 'hasCodingSystemAndVersion⁻¹', 'MedicalProcedure'),
#   ('MedicalProcedure', 'hasSubjectPseudIdentifier', 'Patient'),
#   ('Patient', 'hasSubjectPseudIdentifier⁻¹', 'DrugPrescription')],
#  [('Diagnosis', 'hasCodingSystemAndVersion', 'CodingSystem'),
#   ('CodingSystem', 'hasCodingSystemAndVersion⁻¹', 'Code'),
#   ('Code', 'hasCodingSystemAndVersion', 'CodingSystem'),
#   ('CodingSystem', 'hasCodingSystemAndVersion⁻¹', 'Diagnosis')],
#  [('Diagnosis', 'hasCodingSystemAndVersion', 'CodingSystem'),
#   ('CodingSystem', 'hasCodingSystemAndVersion⁻¹', 'Code'),
#   ('Code', 'hasCodingSystemAndVersion', 'CodingSystem'),
#   ('CodingSystem', 'hasCodingSystemAndVersion⁻¹', 'MedicalProcedure')],
#  [('Diagnosis', 'hasCodingSystemAndVersion', 'CodingSystem'),
#   ('CodingSystem', 'hasCodingSystemAndVersion⁻¹', 'Code'),
#   ('Code', 'hasCodingSystemAndVersion', 'CodingSystem'),
#   ('CodingSystem', 'hasCodingSystemAndVersion⁻¹', 'Code')],
#  [('Diagnosis', 'hasCodingSystemAndVersion', 'CodingSystem'),
#   ('CodingSystem', 'hasCodingSystemAndVersion⁻¹', 'Code'),
#   ('Code', 'hasCode⁻¹', 'LabResult'),
#   ('LabResult', 'hasCode', 'Code')],
#  [('Diagnosis', 'hasCodingSystemAndVersion', 'CodingSystem'),
#   ('CodingSystem', 'hasCodingSystemAndVersion⁻¹', 'Code'),
#   ('Code', 'hasCode⁻¹', 'LabResult'),
#   ('LabResult', 'hasLabTest⁻¹', 'LabTestEvent')],
#  [('Diagnosis', 'hasCodingSystemAndVersion', 'CodingSystem'),
#   ('CodingSystem', 'hasCodingSystemAndVersion⁻¹', 'Code'),
#   ('Code', 'hasCode⁻¹', 'Drug'),
#   ('Drug', 'hasActiveIngredient', 'Substance')],
#  [('Diagnosis', 'hasCodingSystemAndVersion', 'CodingSystem'),
#   ('CodingSystem', 'hasCodingSystemAndVersion⁻¹', 'Code'),
#   ('Code', 'hasCode⁻¹', 'Drug'),
#   ('Drug', 'hasCode', 'Code')],
#  [('Diagnosis', 'hasCodingSystemAndVersion', 'CodingSystem'),
#   ('CodingSystem', 'hasCodingSystemAndVersion⁻¹', 'Code'),
#   ('Code', 'hasCode⁻¹', 'Drug'),
#   ('Drug', 'hasDrug⁻¹', 'DrugPrescription')],
#  [('Diagnosis', 'hasCodingSystemAndVersion', 'CodingSystem'),
#   ('CodingSystem', 'hasCodingSystemAndVersion⁻¹', 'Code'),
#   ('Code', 'hasCode⁻¹', 'MedicalProcedure'),
#   ('MedicalProcedure', 'hasCode', 'Code')],
#  [('Diagnosis', 'hasCodingSystemAndVersion', 'CodingSystem'),
#   ('CodingSystem', 'hasCodingSystemAndVersion⁻¹', 'Code'),
#   ('Code', 'hasCode⁻¹', 'MedicalProcedure'),
#   ('MedicalProcedure', 'hasCodingSystemAndVersion', 'CodingSystem')],
#  [('Diagnosis', 'hasCodingSystemAndVersion', 'CodingSystem'),
#   ('CodingSystem', 'hasCodingSystemAndVersion⁻¹', 'Code'),
#   ('Code', 'hasCode⁻¹', 'MedicalProcedure'),
#   ('MedicalProcedure', 'hasSubjectPseudIdentifier', 'Patient')],
#  [('Diagnosis', 'hasCodingSystemAndVersion', 'CodingSystem'),
#   ('CodingSystem', 'hasCodingSystemAndVersion⁻¹', 'Code'),
#   ('Code', 'hasCode⁻¹', 'Diagnosis'),
#   ('Diagnosis', 'hasCode', 'Code')],
#  [('Diagnosis', 'hasCodingSystemAndVersion', 'CodingSystem'),
#   ('CodingSystem', 'hasCodingSystemAndVersion⁻¹', 'Code'),
#   ('Code', 'hasCode⁻¹', 'Diagnosis'),
#   ('Diagnosis', 'hasCodingSystemAndVersion', 'CodingSystem')],
#  [('Diagnosis', 'hasCodingSystemAndVersion', 'CodingSystem'),
#   ('CodingSystem', 'hasCodingSystemAndVersion⁻¹', 'Code'),
#   ('Code', 'hasCode⁻¹', 'Diagnosis'),
#   ('Diagnosis', 'hasSubjectPseudIdentifier', 'Patient')],
#  [('Diagnosis', 'hasSubjectPseudIdentifier', 'Patient'),
#   ('Patient', 'hasSubjectPseudIdentifier⁻¹', 'LabTestEvent'),
#   ('LabTestEvent', 'hasLabTest', 'LabResult'),
#   ('LabResult', 'hasCode', 'Code')],
#  [('Diagnosis', 'hasSubjectPseudIdentifier', 'Patient'),
#   ('Patient', 'hasSubjectPseudIdentifier⁻¹', 'LabTestEvent'),
#   ('LabTestEvent', 'hasLabTest', 'LabResult'),
#   ('LabResult', 'hasLabTest⁻¹', 'LabTestEvent')],
#  [('Diagnosis', 'hasSubjectPseudIdentifier', 'Patient'),
#   ('Patient', 'hasSubjectPseudIdentifier⁻¹', 'LabTestEvent'),
#   ('LabTestEvent', 'hasSubjectPseudIdentifier', 'Patient'),
#   ('Patient', 'hasSubjectPseudIdentifier⁻¹', 'LabTestEvent')],
#  [('Diagnosis', 'hasSubjectPseudIdentifier', 'Patient'),
#   ('Patient', 'hasSubjectPseudIdentifier⁻¹', 'LabTestEvent'),
#   ('LabTestEvent', 'hasSubjectPseudIdentifier', 'Patient'),
#   ('Patient', 'hasSubjectPseudIdentifier⁻¹', 'MedicalProcedure')],
#  [('Diagnosis', 'hasSubjectPseudIdentifier', 'Patient'),
#   ('Patient', 'hasSubjectPseudIdentifier⁻¹', 'LabTestEvent'),
#   ('LabTestEvent', 'hasSubjectPseudIdentifier', 'Patient'),
#   ('Patient', 'hasSubjectPseudIdentifier⁻¹', 'Diagnosis')],
#  [('Diagnosis', 'hasSubjectPseudIdentifier', 'Patient'),
#   ('Patient', 'hasSubjectPseudIdentifier⁻¹', 'LabTestEvent'),
#   ('LabTestEvent', 'hasSubjectPseudIdentifier', 'Patient'),
#   ('Patient', 'hasSubjectPseudIdentifier⁻¹', 'DrugPrescription')],
#  [('Diagnosis', 'hasSubjectPseudIdentifier', 'Patient'),
#   ('Patient', 'hasSubjectPseudIdentifier⁻¹', 'MedicalProcedure'),
#   ('MedicalProcedure', 'hasCode', 'Code'),
#   ('Code', 'hasCodingSystemAndVersion', 'CodingSystem')],
#  [('Diagnosis', 'hasSubjectPseudIdentifier', 'Patient'),
#   ('Patient', 'hasSubjectPseudIdentifier⁻¹', 'MedicalProcedure'),
#   ('MedicalProcedure', 'hasCode', 'Code'),
#   ('Code', 'hasCode⁻¹', 'LabResult')],
#  [('Diagnosis', 'hasSubjectPseudIdentifier', 'Patient'),
#   ('Patient', 'hasSubjectPseudIdentifier⁻¹', 'MedicalProcedure'),
#   ('MedicalProcedure', 'hasCode', 'Code'),
#   ('Code', 'hasCode⁻¹', 'Drug')],
#  [('Diagnosis', 'hasSubjectPseudIdentifier', 'Patient'),
#   ('Patient', 'hasSubjectPseudIdentifier⁻¹', 'MedicalProcedure'),
#   ('MedicalProcedure', 'hasCode', 'Code'),
#   ('Code', 'hasCode⁻¹', 'MedicalProcedure')],
#  [('Diagnosis', 'hasSubjectPseudIdentifier', 'Patient'),
#   ('Patient', 'hasSubjectPseudIdentifier⁻¹', 'MedicalProcedure'),
#   ('MedicalProcedure', 'hasCode', 'Code'),
#   ('Code', 'hasCode⁻¹', 'Diagnosis')],
#  [('Diagnosis', 'hasSubjectPseudIdentifier', 'Patient'),
#   ('Patient', 'hasSubjectPseudIdentifier⁻¹', 'MedicalProcedure'),
#   ('MedicalProcedure', 'hasCodingSystemAndVersion', 'CodingSystem'),
#   ('CodingSystem', 'hasCodingSystemAndVersion⁻¹', 'Diagnosis')],
#  [('Diagnosis', 'hasSubjectPseudIdentifier', 'Patient'),
#   ('Patient', 'hasSubjectPseudIdentifier⁻¹', 'MedicalProcedure'),
#   ('MedicalProcedure', 'hasCodingSystemAndVersion', 'CodingSystem'),
#   ('CodingSystem', 'hasCodingSystemAndVersion⁻¹', 'MedicalProcedure')],
#  [('Diagnosis', 'hasSubjectPseudIdentifier', 'Patient'),
#   ('Patient', 'hasSubjectPseudIdentifier⁻¹', 'MedicalProcedure'),
#   ('MedicalProcedure', 'hasCodingSystemAndVersion', 'CodingSystem'),
#   ('CodingSystem', 'hasCodingSystemAndVersion⁻¹', 'Code')],
#  [('Diagnosis', 'hasSubjectPseudIdentifier', 'Patient'),
#   ('Patient', 'hasSubjectPseudIdentifier⁻¹', 'MedicalProcedure'),
#   ('MedicalProcedure', 'hasSubjectPseudIdentifier', 'Patient'),
#   ('Patient', 'hasSubjectPseudIdentifier⁻¹', 'LabTestEvent')],
#  [('Diagnosis', 'hasSubjectPseudIdentifier', 'Patient'),
#   ('Patient', 'hasSubjectPseudIdentifier⁻¹', 'MedicalProcedure'),
#   ('MedicalProcedure', 'hasSubjectPseudIdentifier', 'Patient'),
#   ('Patient', 'hasSubjectPseudIdentifier⁻¹', 'MedicalProcedure')],
#  [('Diagnosis', 'hasSubjectPseudIdentifier', 'Patient'),
#   ('Patient', 'hasSubjectPseudIdentifier⁻¹', 'MedicalProcedure'),
#   ('MedicalProcedure', 'hasSubjectPseudIdentifier', 'Patient'),
#   ('Patient', 'hasSubjectPseudIdentifier⁻¹', 'Diagnosis')],
#  [('Diagnosis', 'hasSubjectPseudIdentifier', 'Patient'),
#   ('Patient', 'hasSubjectPseudIdentifier⁻¹', 'MedicalProcedure'),
#   ('MedicalProcedure', 'hasSubjectPseudIdentifier', 'Patient'),
#   ('Patient', 'hasSubjectPseudIdentifier⁻¹', 'DrugPrescription')],
#  [('Diagnosis', 'hasSubjectPseudIdentifier', 'Patient'),
#   ('Patient', 'hasSubjectPseudIdentifier⁻¹', 'Diagnosis'),
#   ('Diagnosis', 'hasCode', 'Code'),
#   ('Code', 'hasCodingSystemAndVersion', 'CodingSystem')],
#  [('Diagnosis', 'hasSubjectPseudIdentifier', 'Patient'),
#   ('Patient', 'hasSubjectPseudIdentifier⁻¹', 'Diagnosis'),
#   ('Diagnosis', 'hasCode', 'Code'),
#   ('Code', 'hasCode⁻¹', 'LabResult')],
#  [('Diagnosis', 'hasSubjectPseudIdentifier', 'Patient'),
#   ('Patient', 'hasSubjectPseudIdentifier⁻¹', 'Diagnosis'),
#   ('Diagnosis', 'hasCode', 'Code'),
#   ('Code', 'hasCode⁻¹', 'Drug')],
#  [('Diagnosis', 'hasSubjectPseudIdentifier', 'Patient'),
#   ('Patient', 'hasSubjectPseudIdentifier⁻¹', 'Diagnosis'),
#   ('Diagnosis', 'hasCode', 'Code'),
#   ('Code', 'hasCode⁻¹', 'MedicalProcedure')],
#  [('Diagnosis', 'hasSubjectPseudIdentifier', 'Patient'),
#   ('Patient', 'hasSubjectPseudIdentifier⁻¹', 'Diagnosis'),
#   ('Diagnosis', 'hasCode', 'Code'),
#   ('Code', 'hasCode⁻¹', 'Diagnosis')],
#  [('Diagnosis', 'hasSubjectPseudIdentifier', 'Patient'),
#   ('Patient', 'hasSubjectPseudIdentifier⁻¹', 'Diagnosis'),
#   ('Diagnosis', 'hasCodingSystemAndVersion', 'CodingSystem'),
#   ('CodingSystem', 'hasCodingSystemAndVersion⁻¹', 'Diagnosis')],
#  [('Diagnosis', 'hasSubjectPseudIdentifier', 'Patient'),
#   ('Patient', 'hasSubjectPseudIdentifier⁻¹', 'Diagnosis'),
#   ('Diagnosis', 'hasCodingSystemAndVersion', 'CodingSystem'),
#   ('CodingSystem', 'hasCodingSystemAndVersion⁻¹', 'MedicalProcedure')],
#  [('Diagnosis', 'hasSubjectPseudIdentifier', 'Patient'),
#   ('Patient', 'hasSubjectPseudIdentifier⁻¹', 'Diagnosis'),
#   ('Diagnosis', 'hasCodingSystemAndVersion', 'CodingSystem'),
#   ('CodingSystem', 'hasCodingSystemAndVersion⁻¹', 'Code')],
#  [('Diagnosis', 'hasSubjectPseudIdentifier', 'Patient'),
#   ('Patient', 'hasSubjectPseudIdentifier⁻¹', 'Diagnosis'),
#   ('Diagnosis', 'hasSubjectPseudIdentifier', 'Patient'),
#   ('Patient', 'hasSubjectPseudIdentifier⁻¹', 'LabTestEvent')],
#  [('Diagnosis', 'hasSubjectPseudIdentifier', 'Patient'),
#   ('Patient', 'hasSubjectPseudIdentifier⁻¹', 'Diagnosis'),
#   ('Diagnosis', 'hasSubjectPseudIdentifier', 'Patient'),
#   ('Patient', 'hasSubjectPseudIdentifier⁻¹', 'MedicalProcedure')],
#  [('Diagnosis', 'hasSubjectPseudIdentifier', 'Patient'),
#   ('Patient', 'hasSubjectPseudIdentifier⁻¹', 'Diagnosis'),
#   ('Diagnosis', 'hasSubjectPseudIdentifier', 'Patient'),
#   ('Patient', 'hasSubjectPseudIdentifier⁻¹', 'Diagnosis')],
#  [('Diagnosis', 'hasSubjectPseudIdentifier', 'Patient'),
#   ('Patient', 'hasSubjectPseudIdentifier⁻¹', 'Diagnosis'),
#   ('Diagnosis', 'hasSubjectPseudIdentifier', 'Patient'),
#   ('Patient', 'hasSubjectPseudIdentifier⁻¹', 'DrugPrescription')],
#  [('Diagnosis', 'hasSubjectPseudIdentifier', 'Patient'),
#   ('Patient', 'hasSubjectPseudIdentifier⁻¹', 'DrugPrescription'),
#   ('DrugPrescription', 'hasDrug', 'Drug'),
#   ('Drug', 'hasActiveIngredient', 'Substance')],
#  [('Diagnosis', 'hasSubjectPseudIdentifier', 'Patient'),
#   ('Patient', 'hasSubjectPseudIdentifier⁻¹', 'DrugPrescription'),
#   ('DrugPrescription', 'hasDrug', 'Drug'),
#   ('Drug', 'hasCode', 'Code')],
#  [('Diagnosis', 'hasSubjectPseudIdentifier', 'Patient'),
#   ('Patient', 'hasSubjectPseudIdentifier⁻¹', 'DrugPrescription'),
#   ('DrugPrescription', 'hasDrug', 'Drug'),
#   ('Drug', 'hasDrug⁻¹', 'DrugPrescription')],
#  [('Diagnosis', 'hasSubjectPseudIdentifier', 'Patient'),
#   ('Patient', 'hasSubjectPseudIdentifier⁻¹', 'DrugPrescription'),
#   ('DrugPrescription', 'hasSubjectPseudIdentifier', 'Patient'),
#   ('Patient', 'hasSubjectPseudIdentifier⁻¹', 'LabTestEvent')],
#  [('Diagnosis', 'hasSubjectPseudIdentifier', 'Patient'),
#   ('Patient', 'hasSubjectPseudIdentifier⁻¹', 'DrugPrescription'),
#   ('DrugPrescription', 'hasSubjectPseudIdentifier', 'Patient'),
#   ('Patient', 'hasSubjectPseudIdentifier⁻¹', 'MedicalProcedure')],
#  [('Diagnosis', 'hasSubjectPseudIdentifier', 'Patient'),
#   ('Patient', 'hasSubjectPseudIdentifier⁻¹', 'DrugPrescription'),
#   ('DrugPrescription', 'hasSubjectPseudIdentifier', 'Patient'),
#   ('Patient', 'hasSubjectPseudIdentifier⁻¹', 'Diagnosis')],
#  [('Diagnosis', 'hasSubjectPseudIdentifier', 'Patient'),
#   ('Patient', 'hasSubjectPseudIdentifier⁻¹', 'DrugPrescription'),
#   ('DrugPrescription', 'hasSubjectPseudIdentifier', 'Patient'),
#   ('Patient', 'hasSubjectPseudIdentifier⁻¹', 'DrugPrescription')],
#  [('CodingSystem', 'hasCodingSystemAndVersion⁻¹', 'Diagnosis'),
#   ('Diagnosis', 'hasCode', 'Code'),
#   ('Code', 'hasCodingSystemAndVersion', 'CodingSystem'),
#   ('CodingSystem', 'hasCodingSystemAndVersion⁻¹', 'Diagnosis')],
#  [('CodingSystem', 'hasCodingSystemAndVersion⁻¹', 'Diagnosis'),
#   ('Diagnosis', 'hasCode', 'Code'),
#   ('Code', 'hasCodingSystemAndVersion', 'CodingSystem'),
#   ('CodingSystem', 'hasCodingSystemAndVersion⁻¹', 'MedicalProcedure')],
#  [('CodingSystem', 'hasCodingSystemAndVersion⁻¹', 'Diagnosis'),
#   ('Diagnosis', 'hasCode', 'Code'),
#   ('Code', 'hasCodingSystemAndVersion', 'CodingSystem'),
#   ('CodingSystem', 'hasCodingSystemAndVersion⁻¹', 'Code')],
#  [('CodingSystem', 'hasCodingSystemAndVersion⁻¹', 'Diagnosis'),
#   ('Diagnosis', 'hasCode', 'Code'),
#   ('Code', 'hasCode⁻¹', 'LabResult'),
#   ('LabResult', 'hasCode', 'Code')],
#  [('CodingSystem', 'hasCodingSystemAndVersion⁻¹', 'Diagnosis'),
#   ('Diagnosis', 'hasCode', 'Code'),
#   ('Code', 'hasCode⁻¹', 'LabResult'),
#   ('LabResult', 'hasLabTest⁻¹', 'LabTestEvent')],
#  [('CodingSystem', 'hasCodingSystemAndVersion⁻¹', 'Diagnosis'),
#   ('Diagnosis', 'hasCode', 'Code'),
#   ('Code', 'hasCode⁻¹', 'Drug'),
#   ('Drug', 'hasActiveIngredient', 'Substance')],
#  [('CodingSystem', 'hasCodingSystemAndVersion⁻¹', 'Diagnosis'),
#   ('Diagnosis', 'hasCode', 'Code'),
#   ('Code', 'hasCode⁻¹', 'Drug'),
#   ('Drug', 'hasCode', 'Code')],
#  [('CodingSystem', 'hasCodingSystemAndVersion⁻¹', 'Diagnosis'),
#   ('Diagnosis', 'hasCode', 'Code'),
#   ('Code', 'hasCode⁻¹', 'Drug'),
#   ('Drug', 'hasDrug⁻¹', 'DrugPrescription')],
#  [('CodingSystem', 'hasCodingSystemAndVersion⁻¹', 'Diagnosis'),
#   ('Diagnosis', 'hasCode', 'Code'),
#   ('Code', 'hasCode⁻¹', 'MedicalProcedure'),
#   ('MedicalProcedure', 'hasCode', 'Code')],
#  [('CodingSystem', 'hasCodingSystemAndVersion⁻¹', 'Diagnosis'),
#   ('Diagnosis', 'hasCode', 'Code'),
#   ('Code', 'hasCode⁻¹', 'MedicalProcedure'),
#   ('MedicalProcedure', 'hasCodingSystemAndVersion', 'CodingSystem')],
#  [('CodingSystem', 'hasCodingSystemAndVersion⁻¹', 'Diagnosis'),
#   ('Diagnosis', 'hasCode', 'Code'),
#   ('Code', 'hasCode⁻¹', 'MedicalProcedure'),
#   ('MedicalProcedure', 'hasSubjectPseudIdentifier', 'Patient')],
#  [('CodingSystem', 'hasCodingSystemAndVersion⁻¹', 'Diagnosis'),
#   ('Diagnosis', 'hasCode', 'Code'),
#   ('Code', 'hasCode⁻¹', 'Diagnosis'),
#   ('Diagnosis', 'hasCode', 'Code')],
#  [('CodingSystem', 'hasCodingSystemAndVersion⁻¹', 'Diagnosis'),
#   ('Diagnosis', 'hasCode', 'Code'),
#   ('Code', 'hasCode⁻¹', 'Diagnosis'),
#   ('Diagnosis', 'hasCodingSystemAndVersion', 'CodingSystem')],
#  [('CodingSystem', 'hasCodingSystemAndVersion⁻¹', 'Diagnosis'),
#   ('Diagnosis', 'hasCode', 'Code'),
#   ('Code', 'hasCode⁻¹', 'Diagnosis'),
#   ('Diagnosis', 'hasSubjectPseudIdentifier', 'Patient')],
#  [('CodingSystem', 'hasCodingSystemAndVersion⁻¹', 'Diagnosis'),
#   ('Diagnosis', 'hasCodingSystemAndVersion', 'CodingSystem'),
#   ('CodingSystem', 'hasCodingSystemAndVersion⁻¹', 'Diagnosis'),
#   ('Diagnosis', 'hasCode', 'Code')],
#  [('CodingSystem', 'hasCodingSystemAndVersion⁻¹', 'Diagnosis'),
#   ('Diagnosis', 'hasCodingSystemAndVersion', 'CodingSystem'),
#   ('CodingSystem', 'hasCodingSystemAndVersion⁻¹', 'Diagnosis'),
#   ('Diagnosis', 'hasCodingSystemAndVersion', 'CodingSystem')],
#  [('CodingSystem', 'hasCodingSystemAndVersion⁻¹', 'Diagnosis'),
#   ('Diagnosis', 'hasCodingSystemAndVersion', 'CodingSystem'),
#   ('CodingSystem', 'hasCodingSystemAndVersion⁻¹', 'Diagnosis'),
#   ('Diagnosis', 'hasSubjectPseudIdentifier', 'Patient')],
#  [('CodingSystem', 'hasCodingSystemAndVersion⁻¹', 'Diagnosis'),
#   ('Diagnosis', 'hasCodingSystemAndVersion', 'CodingSystem'),
#   ('CodingSystem', 'hasCodingSystemAndVersion⁻¹', 'MedicalProcedure'),
#   ('MedicalProcedure', 'hasCode', 'Code')],
#  [('CodingSystem', 'hasCodingSystemAndVersion⁻¹', 'Diagnosis'),
#   ('Diagnosis', 'hasCodingSystemAndVersion', 'CodingSystem'),
#   ('CodingSystem', 'hasCodingSystemAndVersion⁻¹', 'MedicalProcedure'),
#   ('MedicalProcedure', 'hasCodingSystemAndVersion', 'CodingSystem')],
#  [('CodingSystem', 'hasCodingSystemAndVersion⁻¹', 'Diagnosis'),
#   ('Diagnosis', 'hasCodingSystemAndVersion', 'CodingSystem'),
#   ('CodingSystem', 'hasCodingSystemAndVersion⁻¹', 'MedicalProcedure'),
#   ('MedicalProcedure', 'hasSubjectPseudIdentifier', 'Patient')],
#  [('CodingSystem', 'hasCodingSystemAndVersion⁻¹', 'Diagnosis'),
#   ('Diagnosis', 'hasCodingSystemAndVersion', 'CodingSystem'),
#   ('CodingSystem', 'hasCodingSystemAndVersion⁻¹', 'Code'),
#   ('Code', 'hasCodingSystemAndVersion', 'CodingSystem')],
#  [('CodingSystem', 'hasCodingSystemAndVersion⁻¹', 'Diagnosis'),
#   ('Diagnosis', 'hasCodingSystemAndVersion', 'CodingSystem'),
#   ('CodingSystem', 'hasCodingSystemAndVersion⁻¹', 'Code'),
#   ('Code', 'hasCode⁻¹', 'LabResult')],
#  [('CodingSystem', 'hasCodingSystemAndVersion⁻¹', 'Diagnosis'),
#   ('Diagnosis', 'hasCodingSystemAndVersion', 'CodingSystem'),
#   ('CodingSystem', 'hasCodingSystemAndVersion⁻¹', 'Code'),
#   ('Code', 'hasCode⁻¹', 'Drug')],
#  [('CodingSystem', 'hasCodingSystemAndVersion⁻¹', 'Diagnosis'),
#   ('Diagnosis', 'hasCodingSystemAndVersion', 'CodingSystem'),
#   ('CodingSystem', 'hasCodingSystemAndVersion⁻¹', 'Code'),
#   ('Code', 'hasCode⁻¹', 'MedicalProcedure')],
#  [('CodingSystem', 'hasCodingSystemAndVersion⁻¹', 'Diagnosis'),
#   ('Diagnosis', 'hasCodingSystemAndVersion', 'CodingSystem'),
#   ('CodingSystem', 'hasCodingSystemAndVersion⁻¹', 'Code'),
#   ('Code', 'hasCode⁻¹', 'Diagnosis')],
#  [('CodingSystem', 'hasCodingSystemAndVersion⁻¹', 'Diagnosis'),
#   ('Diagnosis', 'hasSubjectPseudIdentifier', 'Patient'),
#   ('Patient', 'hasSubjectPseudIdentifier⁻¹', 'LabTestEvent'),
#   ('LabTestEvent', 'hasLabTest', 'LabResult')],
#  [('CodingSystem', 'hasCodingSystemAndVersion⁻¹', 'Diagnosis'),
#   ('Diagnosis', 'hasSubjectPseudIdentifier', 'Patient'),
#   ('Patient', 'hasSubjectPseudIdentifier⁻¹', 'LabTestEvent'),
#   ('LabTestEvent', 'hasSubjectPseudIdentifier', 'Patient')],
#  [('CodingSystem', 'hasCodingSystemAndVersion⁻¹', 'Diagnosis'),
#   ('Diagnosis', 'hasSubjectPseudIdentifier', 'Patient'),
#   ('Patient', 'hasSubjectPseudIdentifier⁻¹', 'MedicalProcedure'),
#   ('MedicalProcedure', 'hasCode', 'Code')],
#  [('CodingSystem', 'hasCodingSystemAndVersion⁻¹', 'Diagnosis'),
#   ('Diagnosis', 'hasSubjectPseudIdentifier', 'Patient'),
#   ('Patient', 'hasSubjectPseudIdentifier⁻¹', 'MedicalProcedure'),
#   ('MedicalProcedure', 'hasCodingSystemAndVersion', 'CodingSystem')],
#  [('CodingSystem', 'hasCodingSystemAndVersion⁻¹', 'Diagnosis'),
#   ('Diagnosis', 'hasSubjectPseudIdentifier', 'Patient'),
#   ('Patient', 'hasSubjectPseudIdentifier⁻¹', 'MedicalProcedure'),
#   ('MedicalProcedure', 'hasSubjectPseudIdentifier', 'Patient')],
#  [('CodingSystem', 'hasCodingSystemAndVersion⁻¹', 'Diagnosis'),
#   ('Diagnosis', 'hasSubjectPseudIdentifier', 'Patient'),
#   ('Patient', 'hasSubjectPseudIdentifier⁻¹', 'Diagnosis'),
#   ('Diagnosis', 'hasCode', 'Code')],
#  [('CodingSystem', 'hasCodingSystemAndVersion⁻¹', 'Diagnosis'),
#   ('Diagnosis', 'hasSubjectPseudIdentifier', 'Patient'),
#   ('Patient', 'hasSubjectPseudIdentifier⁻¹', 'Diagnosis'),
#   ('Diagnosis', 'hasCodingSystemAndVersion', 'CodingSystem')],
#  [('CodingSystem', 'hasCodingSystemAndVersion⁻¹', 'Diagnosis'),
#   ('Diagnosis', 'hasSubjectPseudIdentifier', 'Patient'),
#   ('Patient', 'hasSubjectPseudIdentifier⁻¹', 'Diagnosis'),
#   ('Diagnosis', 'hasSubjectPseudIdentifier', 'Patient')],
#  [('CodingSystem', 'hasCodingSystemAndVersion⁻¹', 'Diagnosis'),
#   ('Diagnosis', 'hasSubjectPseudIdentifier', 'Patient'),
#   ('Patient', 'hasSubjectPseudIdentifier⁻¹', 'DrugPrescription'),
#   ('DrugPrescription', 'hasDrug', 'Drug')],
#  [('CodingSystem', 'hasCodingSystemAndVersion⁻¹', 'Diagnosis'),
#   ('Diagnosis', 'hasSubjectPseudIdentifier', 'Patient'),
#   ('Patient', 'hasSubjectPseudIdentifier⁻¹', 'DrugPrescription'),
#   ('DrugPrescription', 'hasSubjectPseudIdentifier', 'Patient')],
#  [('CodingSystem', 'hasCodingSystemAndVersion⁻¹', 'MedicalProcedure'),
#   ('MedicalProcedure', 'hasCode', 'Code'),
#   ('Code', 'hasCodingSystemAndVersion', 'CodingSystem'),
#   ('CodingSystem', 'hasCodingSystemAndVersion⁻¹', 'Diagnosis')],
#  [('CodingSystem', 'hasCodingSystemAndVersion⁻¹', 'MedicalProcedure'),
#   ('MedicalProcedure', 'hasCode', 'Code'),
#   ('Code', 'hasCodingSystemAndVersion', 'CodingSystem'),
#   ('CodingSystem', 'hasCodingSystemAndVersion⁻¹', 'MedicalProcedure')],
#  [('CodingSystem', 'hasCodingSystemAndVersion⁻¹', 'MedicalProcedure'),
#   ('MedicalProcedure', 'hasCode', 'Code'),
#   ('Code', 'hasCodingSystemAndVersion', 'CodingSystem'),
#   ('CodingSystem', 'hasCodingSystemAndVersion⁻¹', 'Code')],
#  [('CodingSystem', 'hasCodingSystemAndVersion⁻¹', 'MedicalProcedure'),
#   ('MedicalProcedure', 'hasCode', 'Code'),
#   ('Code', 'hasCode⁻¹', 'LabResult'),
#   ('LabResult', 'hasCode', 'Code')],
#  [('CodingSystem', 'hasCodingSystemAndVersion⁻¹', 'MedicalProcedure'),
#   ('MedicalProcedure', 'hasCode', 'Code'),
#   ('Code', 'hasCode⁻¹', 'LabResult'),
#   ('LabResult', 'hasLabTest⁻¹', 'LabTestEvent')],
#  [('CodingSystem', 'hasCodingSystemAndVersion⁻¹', 'MedicalProcedure'),
#   ('MedicalProcedure', 'hasCode', 'Code'),
#   ('Code', 'hasCode⁻¹', 'Drug'),
#   ('Drug', 'hasActiveIngredient', 'Substance')],
#  [('CodingSystem', 'hasCodingSystemAndVersion⁻¹', 'MedicalProcedure'),
#   ('MedicalProcedure', 'hasCode', 'Code'),
#   ('Code', 'hasCode⁻¹', 'Drug'),
#   ('Drug', 'hasCode', 'Code')],
#  [('CodingSystem', 'hasCodingSystemAndVersion⁻¹', 'MedicalProcedure'),
#   ('MedicalProcedure', 'hasCode', 'Code'),
#   ('Code', 'hasCode⁻¹', 'Drug'),
#   ('Drug', 'hasDrug⁻¹', 'DrugPrescription')],
#  [('CodingSystem', 'hasCodingSystemAndVersion⁻¹', 'MedicalProcedure'),
#   ('MedicalProcedure', 'hasCode', 'Code'),
#   ('Code', 'hasCode⁻¹', 'MedicalProcedure'),
#   ('MedicalProcedure', 'hasCode', 'Code')],
#  [('CodingSystem', 'hasCodingSystemAndVersion⁻¹', 'MedicalProcedure'),
#   ('MedicalProcedure', 'hasCode', 'Code'),
#   ('Code', 'hasCode⁻¹', 'MedicalProcedure'),
#   ('MedicalProcedure', 'hasCodingSystemAndVersion', 'CodingSystem')],
#  [('CodingSystem', 'hasCodingSystemAndVersion⁻¹', 'MedicalProcedure'),
#   ('MedicalProcedure', 'hasCode', 'Code'),
#   ('Code', 'hasCode⁻¹', 'MedicalProcedure'),
#   ('MedicalProcedure', 'hasSubjectPseudIdentifier', 'Patient')],
#  [('CodingSystem', 'hasCodingSystemAndVersion⁻¹', 'MedicalProcedure'),
#   ('MedicalProcedure', 'hasCode', 'Code'),
#   ('Code', 'hasCode⁻¹', 'Diagnosis'),
#   ('Diagnosis', 'hasCode', 'Code')],
#  [('CodingSystem', 'hasCodingSystemAndVersion⁻¹', 'MedicalProcedure'),
#   ('MedicalProcedure', 'hasCode', 'Code'),
#   ('Code', 'hasCode⁻¹', 'Diagnosis'),
#   ('Diagnosis', 'hasCodingSystemAndVersion', 'CodingSystem')],
#  [('CodingSystem', 'hasCodingSystemAndVersion⁻¹', 'MedicalProcedure'),
#   ('MedicalProcedure', 'hasCode', 'Code'),
#   ('Code', 'hasCode⁻¹', 'Diagnosis'),
#   ('Diagnosis', 'hasSubjectPseudIdentifier', 'Patient')],
#  [('CodingSystem', 'hasCodingSystemAndVersion⁻¹', 'MedicalProcedure'),
#   ('MedicalProcedure', 'hasCodingSystemAndVersion', 'CodingSystem'),
#   ('CodingSystem', 'hasCodingSystemAndVersion⁻¹', 'Diagnosis'),
#   ('Diagnosis', 'hasCode', 'Code')],
#  [('CodingSystem', 'hasCodingSystemAndVersion⁻¹', 'MedicalProcedure'),
#   ('MedicalProcedure', 'hasCodingSystemAndVersion', 'CodingSystem'),
#   ('CodingSystem', 'hasCodingSystemAndVersion⁻¹', 'Diagnosis'),
#   ('Diagnosis', 'hasCodingSystemAndVersion', 'CodingSystem')],
#  [('CodingSystem', 'hasCodingSystemAndVersion⁻¹', 'MedicalProcedure'),
#   ('MedicalProcedure', 'hasCodingSystemAndVersion', 'CodingSystem'),
#   ('CodingSystem', 'hasCodingSystemAndVersion⁻¹', 'Diagnosis'),
#   ('Diagnosis', 'hasSubjectPseudIdentifier', 'Patient')],
#  [('CodingSystem', 'hasCodingSystemAndVersion⁻¹', 'MedicalProcedure'),
#   ('MedicalProcedure', 'hasCodingSystemAndVersion', 'CodingSystem'),
#   ('CodingSystem', 'hasCodingSystemAndVersion⁻¹', 'MedicalProcedure'),
#   ('MedicalProcedure', 'hasCode', 'Code')],
#  [('CodingSystem', 'hasCodingSystemAndVersion⁻¹', 'MedicalProcedure'),
#   ('MedicalProcedure', 'hasCodingSystemAndVersion', 'CodingSystem'),
#   ('CodingSystem', 'hasCodingSystemAndVersion⁻¹', 'MedicalProcedure'),
#   ('MedicalProcedure', 'hasCodingSystemAndVersion', 'CodingSystem')],
#  [('CodingSystem', 'hasCodingSystemAndVersion⁻¹', 'MedicalProcedure'),
#   ('MedicalProcedure', 'hasCodingSystemAndVersion', 'CodingSystem'),
#   ('CodingSystem', 'hasCodingSystemAndVersion⁻¹', 'MedicalProcedure'),
#   ('MedicalProcedure', 'hasSubjectPseudIdentifier', 'Patient')],
#  [('CodingSystem', 'hasCodingSystemAndVersion⁻¹', 'MedicalProcedure'),
#   ('MedicalProcedure', 'hasCodingSystemAndVersion', 'CodingSystem'),
#   ('CodingSystem', 'hasCodingSystemAndVersion⁻¹', 'Code'),
#   ('Code', 'hasCodingSystemAndVersion', 'CodingSystem')],
#  [('CodingSystem', 'hasCodingSystemAndVersion⁻¹', 'MedicalProcedure'),
#   ('MedicalProcedure', 'hasCodingSystemAndVersion', 'CodingSystem'),
#   ('CodingSystem', 'hasCodingSystemAndVersion⁻¹', 'Code'),
#   ('Code', 'hasCode⁻¹', 'LabResult')],
#  [('CodingSystem', 'hasCodingSystemAndVersion⁻¹', 'MedicalProcedure'),
#   ('MedicalProcedure', 'hasCodingSystemAndVersion', 'CodingSystem'),
#   ('CodingSystem', 'hasCodingSystemAndVersion⁻¹', 'Code'),
#   ('Code', 'hasCode⁻¹', 'Drug')],
#  [('CodingSystem', 'hasCodingSystemAndVersion⁻¹', 'MedicalProcedure'),
#   ('MedicalProcedure', 'hasCodingSystemAndVersion', 'CodingSystem'),
#   ('CodingSystem', 'hasCodingSystemAndVersion⁻¹', 'Code'),
#   ('Code', 'hasCode⁻¹', 'MedicalProcedure')],
#  [('CodingSystem', 'hasCodingSystemAndVersion⁻¹', 'MedicalProcedure'),
#   ('MedicalProcedure', 'hasCodingSystemAndVersion', 'CodingSystem'),
#   ('CodingSystem', 'hasCodingSystemAndVersion⁻¹', 'Code'),
#   ('Code', 'hasCode⁻¹', 'Diagnosis')],
#  [('CodingSystem', 'hasCodingSystemAndVersion⁻¹', 'MedicalProcedure'),
#   ('MedicalProcedure', 'hasSubjectPseudIdentifier', 'Patient'),
#   ('Patient', 'hasSubjectPseudIdentifier⁻¹', 'LabTestEvent'),
#   ('LabTestEvent', 'hasLabTest', 'LabResult')],
#  [('CodingSystem', 'hasCodingSystemAndVersion⁻¹', 'MedicalProcedure'),
#   ('MedicalProcedure', 'hasSubjectPseudIdentifier', 'Patient'),
#   ('Patient', 'hasSubjectPseudIdentifier⁻¹', 'LabTestEvent'),
#   ('LabTestEvent', 'hasSubjectPseudIdentifier', 'Patient')],
#  [('CodingSystem', 'hasCodingSystemAndVersion⁻¹', 'MedicalProcedure'),
#   ('MedicalProcedure', 'hasSubjectPseudIdentifier', 'Patient'),
#   ('Patient', 'hasSubjectPseudIdentifier⁻¹', 'MedicalProcedure'),
#   ('MedicalProcedure', 'hasCode', 'Code')],
#  [('CodingSystem', 'hasCodingSystemAndVersion⁻¹', 'MedicalProcedure'),
#   ('MedicalProcedure', 'hasSubjectPseudIdentifier', 'Patient'),
#   ('Patient', 'hasSubjectPseudIdentifier⁻¹', 'MedicalProcedure'),
#   ('MedicalProcedure', 'hasCodingSystemAndVersion', 'CodingSystem')],
#  [('CodingSystem', 'hasCodingSystemAndVersion⁻¹', 'MedicalProcedure'),
#   ('MedicalProcedure', 'hasSubjectPseudIdentifier', 'Patient'),
#   ('Patient', 'hasSubjectPseudIdentifier⁻¹', 'MedicalProcedure'),
#   ('MedicalProcedure', 'hasSubjectPseudIdentifier', 'Patient')],
#  [('CodingSystem', 'hasCodingSystemAndVersion⁻¹', 'MedicalProcedure'),
#   ('MedicalProcedure', 'hasSubjectPseudIdentifier', 'Patient'),
#   ('Patient', 'hasSubjectPseudIdentifier⁻¹', 'Diagnosis'),
#   ('Diagnosis', 'hasCode', 'Code')],
#  [('CodingSystem', 'hasCodingSystemAndVersion⁻¹', 'MedicalProcedure'),
#   ('MedicalProcedure', 'hasSubjectPseudIdentifier', 'Patient'),
#   ('Patient', 'hasSubjectPseudIdentifier⁻¹', 'Diagnosis'),
#   ('Diagnosis', 'hasCodingSystemAndVersion', 'CodingSystem')],
#  [('CodingSystem', 'hasCodingSystemAndVersion⁻¹', 'MedicalProcedure'),
#   ('MedicalProcedure', 'hasSubjectPseudIdentifier', 'Patient'),
#   ('Patient', 'hasSubjectPseudIdentifier⁻¹', 'Diagnosis'),
#   ('Diagnosis', 'hasSubjectPseudIdentifier', 'Patient')],
#  [('CodingSystem', 'hasCodingSystemAndVersion⁻¹', 'MedicalProcedure'),
#   ('MedicalProcedure', 'hasSubjectPseudIdentifier', 'Patient'),
#   ('Patient', 'hasSubjectPseudIdentifier⁻¹', 'DrugPrescription'),
#   ('DrugPrescription', 'hasDrug', 'Drug')],
#  [('CodingSystem', 'hasCodingSystemAndVersion⁻¹', 'MedicalProcedure'),
#   ('MedicalProcedure', 'hasSubjectPseudIdentifier', 'Patient'),
#   ('Patient', 'hasSubjectPseudIdentifier⁻¹', 'DrugPrescription'),
#   ('DrugPrescription', 'hasSubjectPseudIdentifier', 'Patient')],
#  [('CodingSystem', 'hasCodingSystemAndVersion⁻¹', 'Code'),
#   ('Code', 'hasCodingSystemAndVersion', 'CodingSystem'),
#   ('CodingSystem', 'hasCodingSystemAndVersion⁻¹', 'Diagnosis'),
#   ('Diagnosis', 'hasCode', 'Code')],
#  [('CodingSystem', 'hasCodingSystemAndVersion⁻¹', 'Code'),
#   ('Code', 'hasCodingSystemAndVersion', 'CodingSystem'),
#   ('CodingSystem', 'hasCodingSystemAndVersion⁻¹', 'Diagnosis'),
#   ('Diagnosis', 'hasCodingSystemAndVersion', 'CodingSystem')],
#  [('CodingSystem', 'hasCodingSystemAndVersion⁻¹', 'Code'),
#   ('Code', 'hasCodingSystemAndVersion', 'CodingSystem'),
#   ('CodingSystem', 'hasCodingSystemAndVersion⁻¹', 'Diagnosis'),
#   ('Diagnosis', 'hasSubjectPseudIdentifier', 'Patient')],
#  [('CodingSystem', 'hasCodingSystemAndVersion⁻¹', 'Code'),
#   ('Code', 'hasCodingSystemAndVersion', 'CodingSystem'),
#   ('CodingSystem', 'hasCodingSystemAndVersion⁻¹', 'MedicalProcedure'),
#   ('MedicalProcedure', 'hasCode', 'Code')],
#  [('CodingSystem', 'hasCodingSystemAndVersion⁻¹', 'Code'),
#   ('Code', 'hasCodingSystemAndVersion', 'CodingSystem'),
#   ('CodingSystem', 'hasCodingSystemAndVersion⁻¹', 'MedicalProcedure'),
# ...
#   ('CodingSystem', 'hasCodingSystemAndVersion⁻¹', 'MedicalProcedure')],
#  [('LabTestEvent', 'hasSubjectPseudIdentifier', 'Patient'),
#   ('Patient', 'hasSubjectPseudIdentifier⁻¹', 'Diagnosis'),
#   ('Diagnosis', 'hasCodingSystemAndVersion', 'CodingSystem'),
#   ('CodingSystem', 'hasCodingSystemAndVersion⁻¹', 'Code')],
#  [('LabTestEvent', 'hasSubjectPseudIdentifier', 'Patient'),
#   ('Patient', 'hasSubjectPseudIdentifier⁻¹', 'Diagnosis'),
#   ('Diagnosis', 'hasSubjectPseudIdentifier', 'Patient'),
#   ('Patient', 'hasSubjectPseudIdentifier⁻¹', 'LabTestEvent')],
#  [('LabTestEvent', 'hasSubjectPseudIdentifier', 'Patient'),
#   ('Patient', 'hasSubjectPseudIdentifier⁻¹', 'Diagnosis'),
#   ('Diagnosis', 'hasSubjectPseudIdentifier', 'Patient'),
#   ('Patient', 'hasSubjectPseudIdentifier⁻¹', 'MedicalProcedure')],
#  [('LabTestEvent', 'hasSubjectPseudIdentifier', 'Patient'),
#   ('Patient', 'hasSubjectPseudIdentifier⁻¹', 'Diagnosis'),
#   ('Diagnosis', 'hasSubjectPseudIdentifier', 'Patient'),
#   ('Patient', 'hasSubjectPseudIdentifier⁻¹', 'Diagnosis')],
#  [('LabTestEvent', 'hasSubjectPseudIdentifier', 'Patient'),
#   ('Patient', 'hasSubjectPseudIdentifier⁻¹', 'Diagnosis'),
#   ('Diagnosis', 'hasSubjectPseudIdentifier', 'Patient'),
#   ('Patient', 'hasSubjectPseudIdentifier⁻¹', 'DrugPrescription')],
#  [('LabTestEvent', 'hasSubjectPseudIdentifier', 'Patient'),
#   ('Patient', 'hasSubjectPseudIdentifier⁻¹', 'DrugPrescription'),
#   ('DrugPrescription', 'hasDrug', 'Drug'),
#   ('Drug', 'hasActiveIngredient', 'Substance')],
#  [('LabTestEvent', 'hasSubjectPseudIdentifier', 'Patient'),
#   ('Patient', 'hasSubjectPseudIdentifier⁻¹', 'DrugPrescription'),
#   ('DrugPrescription', 'hasDrug', 'Drug'),
#   ('Drug', 'hasCode', 'Code')],
#  [('LabTestEvent', 'hasSubjectPseudIdentifier', 'Patient'),
#   ('Patient', 'hasSubjectPseudIdentifier⁻¹', 'DrugPrescription'),
#   ('DrugPrescription', 'hasDrug', 'Drug'),
#   ('Drug', 'hasDrug⁻¹', 'DrugPrescription')],
#  [('LabTestEvent', 'hasSubjectPseudIdentifier', 'Patient'),
#   ('Patient', 'hasSubjectPseudIdentifier⁻¹', 'DrugPrescription'),
#   ('DrugPrescription', 'hasSubjectPseudIdentifier', 'Patient'),
#   ('Patient', 'hasSubjectPseudIdentifier⁻¹', 'LabTestEvent')],
#  [('LabTestEvent', 'hasSubjectPseudIdentifier', 'Patient'),
#   ('Patient', 'hasSubjectPseudIdentifier⁻¹', 'DrugPrescription'),
#   ('DrugPrescription', 'hasSubjectPseudIdentifier', 'Patient'),
#   ('Patient', 'hasSubjectPseudIdentifier⁻¹', 'MedicalProcedure')],
#  [('LabTestEvent', 'hasSubjectPseudIdentifier', 'Patient'),
#   ('Patient', 'hasSubjectPseudIdentifier⁻¹', 'DrugPrescription'),
#   ('DrugPrescription', 'hasSubjectPseudIdentifier', 'Patient'),
#   ('Patient', 'hasSubjectPseudIdentifier⁻¹', 'Diagnosis')],
#  [('LabTestEvent', 'hasSubjectPseudIdentifier', 'Patient'),
#   ('Patient', 'hasSubjectPseudIdentifier⁻¹', 'DrugPrescription'),
#   ('DrugPrescription', 'hasSubjectPseudIdentifier', 'Patient'),
#   ('Patient', 'hasSubjectPseudIdentifier⁻¹', 'DrugPrescription')],
#  [('DrugPrescription', 'hasDrug', 'Drug'),
#   ('Drug', 'hasActiveIngredient', 'Substance'),
#   ('Substance', 'hasActiveIngredient⁻¹', 'Drug'),
#   ('Drug', 'hasActiveIngredient', 'Substance')],
#  [('DrugPrescription', 'hasDrug', 'Drug'),
#   ('Drug', 'hasActiveIngredient', 'Substance'),
#   ('Substance', 'hasActiveIngredient⁻¹', 'Drug'),
#   ('Drug', 'hasCode', 'Code')],
#  [('DrugPrescription', 'hasDrug', 'Drug'),
#   ('Drug', 'hasActiveIngredient', 'Substance'),
#   ('Substance', 'hasActiveIngredient⁻¹', 'Drug'),
#   ('Drug', 'hasDrug⁻¹', 'DrugPrescription')],
#  [('DrugPrescription', 'hasDrug', 'Drug'),
#   ('Drug', 'hasCode', 'Code'),
#   ('Code', 'hasCodingSystemAndVersion', 'CodingSystem'),
#   ('CodingSystem', 'hasCodingSystemAndVersion⁻¹', 'Diagnosis')],
#  [('DrugPrescription', 'hasDrug', 'Drug'),
#   ('Drug', 'hasCode', 'Code'),
#   ('Code', 'hasCodingSystemAndVersion', 'CodingSystem'),
#   ('CodingSystem', 'hasCodingSystemAndVersion⁻¹', 'MedicalProcedure')],
#  [('DrugPrescription', 'hasDrug', 'Drug'),
#   ('Drug', 'hasCode', 'Code'),
#   ('Code', 'hasCodingSystemAndVersion', 'CodingSystem'),
#   ('CodingSystem', 'hasCodingSystemAndVersion⁻¹', 'Code')],
#  [('DrugPrescription', 'hasDrug', 'Drug'),
#   ('Drug', 'hasCode', 'Code'),
#   ('Code', 'hasCode⁻¹', 'LabResult'),
#   ('LabResult', 'hasCode', 'Code')],
#  [('DrugPrescription', 'hasDrug', 'Drug'),
#   ('Drug', 'hasCode', 'Code'),
#   ('Code', 'hasCode⁻¹', 'LabResult'),
#   ('LabResult', 'hasLabTest⁻¹', 'LabTestEvent')],
#  [('DrugPrescription', 'hasDrug', 'Drug'),
#   ('Drug', 'hasCode', 'Code'),
#   ('Code', 'hasCode⁻¹', 'Drug'),
#   ('Drug', 'hasActiveIngredient', 'Substance')],
#  [('DrugPrescription', 'hasDrug', 'Drug'),
#   ('Drug', 'hasCode', 'Code'),
#   ('Code', 'hasCode⁻¹', 'Drug'),
#   ('Drug', 'hasCode', 'Code')],
#  [('DrugPrescription', 'hasDrug', 'Drug'),
#   ('Drug', 'hasCode', 'Code'),
#   ('Code', 'hasCode⁻¹', 'Drug'),
#   ('Drug', 'hasDrug⁻¹', 'DrugPrescription')],
#  [('DrugPrescription', 'hasDrug', 'Drug'),
#   ('Drug', 'hasCode', 'Code'),
#   ('Code', 'hasCode⁻¹', 'MedicalProcedure'),
#   ('MedicalProcedure', 'hasCode', 'Code')],
#  [('DrugPrescription', 'hasDrug', 'Drug'),
#   ('Drug', 'hasCode', 'Code'),
#   ('Code', 'hasCode⁻¹', 'MedicalProcedure'),
#   ('MedicalProcedure', 'hasCodingSystemAndVersion', 'CodingSystem')],
#  [('DrugPrescription', 'hasDrug', 'Drug'),
#   ('Drug', 'hasCode', 'Code'),
#   ('Code', 'hasCode⁻¹', 'MedicalProcedure'),
#   ('MedicalProcedure', 'hasSubjectPseudIdentifier', 'Patient')],
#  [('DrugPrescription', 'hasDrug', 'Drug'),
#   ('Drug', 'hasCode', 'Code'),
#   ('Code', 'hasCode⁻¹', 'Diagnosis'),
#   ('Diagnosis', 'hasCode', 'Code')],
#  [('DrugPrescription', 'hasDrug', 'Drug'),
#   ('Drug', 'hasCode', 'Code'),
#   ('Code', 'hasCode⁻¹', 'Diagnosis'),
#   ('Diagnosis', 'hasCodingSystemAndVersion', 'CodingSystem')],
#  [('DrugPrescription', 'hasDrug', 'Drug'),
#   ('Drug', 'hasCode', 'Code'),
#   ('Code', 'hasCode⁻¹', 'Diagnosis'),
#   ('Diagnosis', 'hasSubjectPseudIdentifier', 'Patient')],
#  [('DrugPrescription', 'hasDrug', 'Drug'),
#   ('Drug', 'hasDrug⁻¹', 'DrugPrescription'),
#   ('DrugPrescription', 'hasDrug', 'Drug'),
#   ('Drug', 'hasActiveIngredient', 'Substance')],
#  [('DrugPrescription', 'hasDrug', 'Drug'),
#   ('Drug', 'hasDrug⁻¹', 'DrugPrescription'),
#   ('DrugPrescription', 'hasDrug', 'Drug'),
#   ('Drug', 'hasCode', 'Code')],
#  [('DrugPrescription', 'hasDrug', 'Drug'),
#   ('Drug', 'hasDrug⁻¹', 'DrugPrescription'),
#   ('DrugPrescription', 'hasDrug', 'Drug'),
#   ('Drug', 'hasDrug⁻¹', 'DrugPrescription')],
#  [('DrugPrescription', 'hasDrug', 'Drug'),
#   ('Drug', 'hasDrug⁻¹', 'DrugPrescription'),
#   ('DrugPrescription', 'hasSubjectPseudIdentifier', 'Patient'),
#   ('Patient', 'hasSubjectPseudIdentifier⁻¹', 'LabTestEvent')],
#  [('DrugPrescription', 'hasDrug', 'Drug'),
#   ('Drug', 'hasDrug⁻¹', 'DrugPrescription'),
#   ('DrugPrescription', 'hasSubjectPseudIdentifier', 'Patient'),
#   ('Patient', 'hasSubjectPseudIdentifier⁻¹', 'MedicalProcedure')],
#  [('DrugPrescription', 'hasDrug', 'Drug'),
#   ('Drug', 'hasDrug⁻¹', 'DrugPrescription'),
#   ('DrugPrescription', 'hasSubjectPseudIdentifier', 'Patient'),
#   ('Patient', 'hasSubjectPseudIdentifier⁻¹', 'Diagnosis')],
#  [('DrugPrescription', 'hasDrug', 'Drug'),
#   ('Drug', 'hasDrug⁻¹', 'DrugPrescription'),
#   ('DrugPrescription', 'hasSubjectPseudIdentifier', 'Patient'),
#   ('Patient', 'hasSubjectPseudIdentifier⁻¹', 'DrugPrescription')],
#  [('DrugPrescription', 'hasSubjectPseudIdentifier', 'Patient'),
#   ('Patient', 'hasSubjectPseudIdentifier⁻¹', 'LabTestEvent'),
#   ('LabTestEvent', 'hasLabTest', 'LabResult'),
#   ('LabResult', 'hasCode', 'Code')],
#  [('DrugPrescription', 'hasSubjectPseudIdentifier', 'Patient'),
#   ('Patient', 'hasSubjectPseudIdentifier⁻¹', 'LabTestEvent'),
#   ('LabTestEvent', 'hasLabTest', 'LabResult'),
#   ('LabResult', 'hasLabTest⁻¹', 'LabTestEvent')],
#  [('DrugPrescription', 'hasSubjectPseudIdentifier', 'Patient'),
#   ('Patient', 'hasSubjectPseudIdentifier⁻¹', 'LabTestEvent'),
#   ('LabTestEvent', 'hasSubjectPseudIdentifier', 'Patient'),
#   ('Patient', 'hasSubjectPseudIdentifier⁻¹', 'LabTestEvent')],
#  [('DrugPrescription', 'hasSubjectPseudIdentifier', 'Patient'),
#   ('Patient', 'hasSubjectPseudIdentifier⁻¹', 'LabTestEvent'),
#   ('LabTestEvent', 'hasSubjectPseudIdentifier', 'Patient'),
#   ('Patient', 'hasSubjectPseudIdentifier⁻¹', 'MedicalProcedure')],
#  [('DrugPrescription', 'hasSubjectPseudIdentifier', 'Patient'),
#   ('Patient', 'hasSubjectPseudIdentifier⁻¹', 'LabTestEvent'),
#   ('LabTestEvent', 'hasSubjectPseudIdentifier', 'Patient'),
#   ('Patient', 'hasSubjectPseudIdentifier⁻¹', 'Diagnosis')],
#  [('DrugPrescription', 'hasSubjectPseudIdentifier', 'Patient'),
#   ('Patient', 'hasSubjectPseudIdentifier⁻¹', 'LabTestEvent'),
#   ('LabTestEvent', 'hasSubjectPseudIdentifier', 'Patient'),
#   ('Patient', 'hasSubjectPseudIdentifier⁻¹', 'DrugPrescription')],
#  [('DrugPrescription', 'hasSubjectPseudIdentifier', 'Patient'),
#   ('Patient', 'hasSubjectPseudIdentifier⁻¹', 'MedicalProcedure'),
#   ('MedicalProcedure', 'hasCode', 'Code'),
#   ('Code', 'hasCodingSystemAndVersion', 'CodingSystem')],
#  [('DrugPrescription', 'hasSubjectPseudIdentifier', 'Patient'),
#   ('Patient', 'hasSubjectPseudIdentifier⁻¹', 'MedicalProcedure'),
#   ('MedicalProcedure', 'hasCode', 'Code'),
#   ('Code', 'hasCode⁻¹', 'LabResult')],
#  [('DrugPrescription', 'hasSubjectPseudIdentifier', 'Patient'),
#   ('Patient', 'hasSubjectPseudIdentifier⁻¹', 'MedicalProcedure'),
#   ('MedicalProcedure', 'hasCode', 'Code'),
#   ('Code', 'hasCode⁻¹', 'Drug')],
#  [('DrugPrescription', 'hasSubjectPseudIdentifier', 'Patient'),
#   ('Patient', 'hasSubjectPseudIdentifier⁻¹', 'MedicalProcedure'),
#   ('MedicalProcedure', 'hasCode', 'Code'),
#   ('Code', 'hasCode⁻¹', 'MedicalProcedure')],
#  [('DrugPrescription', 'hasSubjectPseudIdentifier', 'Patient'),
#   ('Patient', 'hasSubjectPseudIdentifier⁻¹', 'MedicalProcedure'),
#   ('MedicalProcedure', 'hasCode', 'Code'),
#   ('Code', 'hasCode⁻¹', 'Diagnosis')],
#  [('DrugPrescription', 'hasSubjectPseudIdentifier', 'Patient'),
#   ('Patient', 'hasSubjectPseudIdentifier⁻¹', 'MedicalProcedure'),
#   ('MedicalProcedure', 'hasCodingSystemAndVersion', 'CodingSystem'),
#   ('CodingSystem', 'hasCodingSystemAndVersion⁻¹', 'Diagnosis')],
#  [('DrugPrescription', 'hasSubjectPseudIdentifier', 'Patient'),
#   ('Patient', 'hasSubjectPseudIdentifier⁻¹', 'MedicalProcedure'),
#   ('MedicalProcedure', 'hasCodingSystemAndVersion', 'CodingSystem'),
#   ('CodingSystem', 'hasCodingSystemAndVersion⁻¹', 'MedicalProcedure')],
#  [('DrugPrescription', 'hasSubjectPseudIdentifier', 'Patient'),
#   ('Patient', 'hasSubjectPseudIdentifier⁻¹', 'MedicalProcedure'),
#   ('MedicalProcedure', 'hasCodingSystemAndVersion', 'CodingSystem'),
#   ('CodingSystem', 'hasCodingSystemAndVersion⁻¹', 'Code')],
#  [('DrugPrescription', 'hasSubjectPseudIdentifier', 'Patient'),
#   ('Patient', 'hasSubjectPseudIdentifier⁻¹', 'MedicalProcedure'),
#   ('MedicalProcedure', 'hasSubjectPseudIdentifier', 'Patient'),
#   ('Patient', 'hasSubjectPseudIdentifier⁻¹', 'LabTestEvent')],
#  [('DrugPrescription', 'hasSubjectPseudIdentifier', 'Patient'),
#   ('Patient', 'hasSubjectPseudIdentifier⁻¹', 'MedicalProcedure'),
#   ('MedicalProcedure', 'hasSubjectPseudIdentifier', 'Patient'),
#   ('Patient', 'hasSubjectPseudIdentifier⁻¹', 'MedicalProcedure')],
#  [('DrugPrescription', 'hasSubjectPseudIdentifier', 'Patient'),
#   ('Patient', 'hasSubjectPseudIdentifier⁻¹', 'MedicalProcedure'),
#   ('MedicalProcedure', 'hasSubjectPseudIdentifier', 'Patient'),
#   ('Patient', 'hasSubjectPseudIdentifier⁻¹', 'Diagnosis')],
#  [('DrugPrescription', 'hasSubjectPseudIdentifier', 'Patient'),
#   ('Patient', 'hasSubjectPseudIdentifier⁻¹', 'MedicalProcedure'),
#   ('MedicalProcedure', 'hasSubjectPseudIdentifier', 'Patient'),
#   ('Patient', 'hasSubjectPseudIdentifier⁻¹', 'DrugPrescription')],
#  [('DrugPrescription', 'hasSubjectPseudIdentifier', 'Patient'),
#   ('Patient', 'hasSubjectPseudIdentifier⁻¹', 'Diagnosis'),
#   ('Diagnosis', 'hasCode', 'Code'),
#   ('Code', 'hasCodingSystemAndVersion', 'CodingSystem')],
#  [('DrugPrescription', 'hasSubjectPseudIdentifier', 'Patient'),
#   ('Patient', 'hasSubjectPseudIdentifier⁻¹', 'Diagnosis'),
#   ('Diagnosis', 'hasCode', 'Code'),
#   ('Code', 'hasCode⁻¹', 'LabResult')],
#  [('DrugPrescription', 'hasSubjectPseudIdentifier', 'Patient'),
#   ('Patient', 'hasSubjectPseudIdentifier⁻¹', 'Diagnosis'),
#   ('Diagnosis', 'hasCode', 'Code'),
#   ('Code', 'hasCode⁻¹', 'Drug')],
#  [('DrugPrescription', 'hasSubjectPseudIdentifier', 'Patient'),
#   ('Patient', 'hasSubjectPseudIdentifier⁻¹', 'Diagnosis'),
#   ('Diagnosis', 'hasCode', 'Code'),
#   ('Code', 'hasCode⁻¹', 'MedicalProcedure')],
#  [('DrugPrescription', 'hasSubjectPseudIdentifier', 'Patient'),
#   ('Patient', 'hasSubjectPseudIdentifier⁻¹', 'Diagnosis'),
#   ('Diagnosis', 'hasCode', 'Code'),
#   ('Code', 'hasCode⁻¹', 'Diagnosis')],
#  [('DrugPrescription', 'hasSubjectPseudIdentifier', 'Patient'),
#   ('Patient', 'hasSubjectPseudIdentifier⁻¹', 'Diagnosis'),
#   ('Diagnosis', 'hasCodingSystemAndVersion', 'CodingSystem'),
#   ('CodingSystem', 'hasCodingSystemAndVersion⁻¹', 'Diagnosis')],
#  [('DrugPrescription', 'hasSubjectPseudIdentifier', 'Patient'),
#   ('Patient', 'hasSubjectPseudIdentifier⁻¹', 'Diagnosis'),
#   ('Diagnosis', 'hasCodingSystemAndVersion', 'CodingSystem'),
#   ('CodingSystem', 'hasCodingSystemAndVersion⁻¹', 'MedicalProcedure')],
#  [('DrugPrescription', 'hasSubjectPseudIdentifier', 'Patient'),
#   ('Patient', 'hasSubjectPseudIdentifier⁻¹', 'Diagnosis'),
#   ('Diagnosis', 'hasCodingSystemAndVersion', 'CodingSystem'),
#   ('CodingSystem', 'hasCodingSystemAndVersion⁻¹', 'Code')],
#  [('DrugPrescription', 'hasSubjectPseudIdentifier', 'Patient'),
#   ('Patient', 'hasSubjectPseudIdentifier⁻¹', 'Diagnosis'),
#   ('Diagnosis', 'hasSubjectPseudIdentifier', 'Patient'),
#   ('Patient', 'hasSubjectPseudIdentifier⁻¹', 'LabTestEvent')],
#  [('DrugPrescription', 'hasSubjectPseudIdentifier', 'Patient'),
#   ('Patient', 'hasSubjectPseudIdentifier⁻¹', 'Diagnosis'),
#   ('Diagnosis', 'hasSubjectPseudIdentifier', 'Patient'),
#   ('Patient', 'hasSubjectPseudIdentifier⁻¹', 'MedicalProcedure')],
#  [('DrugPrescription', 'hasSubjectPseudIdentifier', 'Patient'),
#   ('Patient', 'hasSubjectPseudIdentifier⁻¹', 'Diagnosis'),
#   ('Diagnosis', 'hasSubjectPseudIdentifier', 'Patient'),
#   ('Patient', 'hasSubjectPseudIdentifier⁻¹', 'Diagnosis')],
#  [('DrugPrescription', 'hasSubjectPseudIdentifier', 'Patient'),
#   ('Patient', 'hasSubjectPseudIdentifier⁻¹', 'Diagnosis'),
#   ('Diagnosis', 'hasSubjectPseudIdentifier', 'Patient'),
#   ('Patient', 'hasSubjectPseudIdentifier⁻¹', 'DrugPrescription')],
#  [('DrugPrescription', 'hasSubjectPseudIdentifier', 'Patient'),
#   ('Patient', 'hasSubjectPseudIdentifier⁻¹', 'DrugPrescription'),
#   ('DrugPrescription', 'hasDrug', 'Drug'),
#   ('Drug', 'hasActiveIngredient', 'Substance')],
#  [('DrugPrescription', 'hasSubjectPseudIdentifier', 'Patient'),
#   ('Patient', 'hasSubjectPseudIdentifier⁻¹', 'DrugPrescription'),
#   ('DrugPrescription', 'hasDrug', 'Drug'),
#   ('Drug', 'hasCode', 'Code')],
#  [('DrugPrescription', 'hasSubjectPseudIdentifier', 'Patient'),
#   ('Patient', 'hasSubjectPseudIdentifier⁻¹', 'DrugPrescription'),
#   ('DrugPrescription', 'hasDrug', 'Drug'),
#   ('Drug', 'hasDrug⁻¹', 'DrugPrescription')],
#  [('DrugPrescription', 'hasSubjectPseudIdentifier', 'Patient'),
#   ('Patient', 'hasSubjectPseudIdentifier⁻¹', 'DrugPrescription'),
#   ('DrugPrescription', 'hasSubjectPseudIdentifier', 'Patient'),
#   ('Patient', 'hasSubjectPseudIdentifier⁻¹', 'LabTestEvent')],
#  [('DrugPrescription', 'hasSubjectPseudIdentifier', 'Patient'),
#   ('Patient', 'hasSubjectPseudIdentifier⁻¹', 'DrugPrescription'),
#   ('DrugPrescription', 'hasSubjectPseudIdentifier', 'Patient'),
#   ('Patient', 'hasSubjectPseudIdentifier⁻¹', 'MedicalProcedure')],
#  [('DrugPrescription', 'hasSubjectPseudIdentifier', 'Patient'),
#   ('Patient', 'hasSubjectPseudIdentifier⁻¹', 'DrugPrescription'),
#   ('DrugPrescription', 'hasSubjectPseudIdentifier', 'Patient'),
#   ('Patient', 'hasSubjectPseudIdentifier⁻¹', 'Diagnosis')],
#  [('DrugPrescription', 'hasSubjectPseudIdentifier', 'Patient'),
#   ('Patient', 'hasSubjectPseudIdentifier⁻¹', 'DrugPrescription'),
#   ('DrugPrescription', 'hasSubjectPseudIdentifier', 'Patient'),
#   ('Patient', 'hasSubjectPseudIdentifier⁻¹', 'DrugPrescription')]]

# %%
import pandas as pd
def create_chain_queries_dataframe(chain_dict):
    """
    Convert chain queries dictionary to DataFrame
    Each row represents one complete chain query
    """
    rows = []
    
    for hop_count, queries in chain_dict.items():
        for query_idx, query_path in enumerate(queries):
            # Create a single row for the entire chain query
            # Extract start and end entities
            start_entity = query_path[0][0] if query_path else None
            end_entity = query_path[-1][2] if query_path else None
            
            # Create path representation
            path_str = ' -> '.join([f"{s}--{r}--> {t}" for s, r, t in query_path])
            
            # Create entities sequence
            entities_sequence = [query_path[0][0]] + [hop[2] for hop in query_path] if query_path else []
            
            # Create relations sequence
            relations_sequence = [hop[1] for hop in query_path] if query_path else []
            
            rows.append({
                'hop_count': hop_count,
                'start_entity': start_entity,
                'end_entity': end_entity,
                'path_representation': path_str,
                'entities_sequence': ','.join(entities_sequence),
                'relations_sequence': ','.join(relations_sequence),
                'query_tuples': str(query_path)  # Keep original format for reference
            })
    
    return pd.DataFrame(rows)

def create_star_queries_dataframe(star_dict):
    """
    Convert star queries dictionary to DataFrame
    Each row represents one complete star query with all arms
    """
    rows = []
    
    for center_entity, queries in star_dict.items():
        for query_idx, query_info in enumerate(queries):
            center = query_info['center']
            arms = query_info['arms']
            num_arms = query_info['num_arms']
            
            # Create one row for the entire star query
            # Extract relations and target entities
            relations = [relation for relation, target in arms]
            targets = [target for relation, target in arms]
            
            # Create various representations
            arms_tuples = str(arms)  # Keep original format
            arms_summary = ','.join([f"{center}--{r}--> {t}" for r, t in arms])
            relations_list = ','.join(relations)
            targets_list = ','.join(targets)
            
            rows.append({
                'center_entity': center,
                'num_arms': num_arms,
                'relations': relations_list,
                'target_entities': targets_list,
                'star_representation': arms_summary,
                'arms_tuples': arms_tuples  # Keep original format for reference
            })
    
    return pd.DataFrame(rows)

# %%
chain_df = create_chain_queries_dataframe(chain_queries)

# %%
chain_df
# Out:
#       hop_count      start_entity        end_entity  \
# 0             1         Substance              Drug
# 1             1         Diagnosis              Code
# 2             1         Diagnosis      CodingSystem
# 3             1         Diagnosis           Patient
# 4             1      CodingSystem         Diagnosis
# ...         ...               ...               ...
# 1307          4  DrugPrescription  DrugPrescription
# 1308          4  DrugPrescription      LabTestEvent
# 1309          4  DrugPrescription  MedicalProcedure
# 1310          4  DrugPrescription         Diagnosis
# 1311          4  DrugPrescription  DrugPrescription
#
#                                     path_representation  \
# 0              Substance--hasActiveIngredient⁻¹--> Drug
# 1                            Diagnosis--hasCode--> Code
# 2     Diagnosis--hasCodingSystemAndVersion--> Coding...
# 3       Diagnosis--hasSubjectPseudIdentifier--> Patient
# 4     CodingSystem--hasCodingSystemAndVersion⁻¹--> D...
# ...                                                 ...
# 1307  DrugPrescription--hasSubjectPseudIdentifier-->...
# 1308  DrugPrescription--hasSubjectPseudIdentifier-->...
# 1309  DrugPrescription--hasSubjectPseudIdentifier-->...
# 1310  DrugPrescription--hasSubjectPseudIdentifier-->...
# 1311  DrugPrescription--hasSubjectPseudIdentifier-->...
#
#                                       entities_sequence  \
# 0                                        Substance,Drug
# 1                                        Diagnosis,Code
# 2                                Diagnosis,CodingSystem
# 3                                     Diagnosis,Patient
# 4                                CodingSystem,Diagnosis
# ...                                                 ...
# 1307  DrugPrescription,Patient,DrugPrescription,Drug...
# 1308  DrugPrescription,Patient,DrugPrescription,Pati...
# 1309  DrugPrescription,Patient,DrugPrescription,Pati...
# 1310  DrugPrescription,Patient,DrugPrescription,Pati...
# 1311  DrugPrescription,Patient,DrugPrescription,Pati...
#
#                                      relations_sequence  \
# 0                                 hasActiveIngredient⁻¹
# 1                                               hasCode
# 2                             hasCodingSystemAndVersion
# 3                             hasSubjectPseudIdentifier
# 4                           hasCodingSystemAndVersion⁻¹
# ...                                                 ...
# 1307  hasSubjectPseudIdentifier,hasSubjectPseudIdent...
# 1308  hasSubjectPseudIdentifier,hasSubjectPseudIdent...
# 1309  hasSubjectPseudIdentifier,hasSubjectPseudIdent...
# 1310  hasSubjectPseudIdentifier,hasSubjectPseudIdent...
# 1311  hasSubjectPseudIdentifier,hasSubjectPseudIdent...
#
#                                            query_tuples
# 0      [('Substance', 'hasActiveIngredient⁻¹', 'Drug')]
# 1                    [('Diagnosis', 'hasCode', 'Code')]
# 2     [('Diagnosis', 'hasCodingSystemAndVersion', 'C...
# 3     [('Diagnosis', 'hasSubjectPseudIdentifier', 'P...
# 4     [('CodingSystem', 'hasCodingSystemAndVersion⁻¹...
# ...                                                 ...
# 1307  [('DrugPrescription', 'hasSubjectPseudIdentifi...
# 1308  [('DrugPrescription', 'hasSubjectPseudIdentifi...
# 1309  [('DrugPrescription', 'hasSubjectPseudIdentifi...
# 1310  [('DrugPrescription', 'hasSubjectPseudIdentifi...
# 1311  [('DrugPrescription', 'hasSubjectPseudIdentifi...
#
# [1312 rows x 7 columns]

# %%
star_df = create_star_queries_dataframe(star_queries)

# %%
star_df
# Out:
#        center_entity  num_arms  \
# 0          Diagnosis         2
# 1          Diagnosis         2
# 2          Diagnosis         2
# 3          Diagnosis         3
# 4       CodingSystem         2
# 5       CodingSystem         2
# 6       CodingSystem         2
# 7       CodingSystem         3
# 8            Patient         2
# 9            Patient         2
# 10           Patient         2
# 11           Patient         2
# 12           Patient         2
# 13           Patient         2
# 14           Patient         3
# 15           Patient         3
# 16           Patient         3
# 17           Patient         3
# 18           Patient         4
# 19  MedicalProcedure         2
# 20  MedicalProcedure         2
# 21  MedicalProcedure         2
# 22  MedicalProcedure         3
# 23         LabResult         2
# 24              Drug         2
# 25              Drug         2
# 26              Drug         2
# 27              Drug         3
# 28              Code         2
# 29              Code         2
# 30              Code         2
# 31              Code         2
# 32              Code         2
# 33              Code         2
# 34              Code         2
# 35              Code         2
# 36              Code         2
# 37              Code         2
# 38              Code         3
# 39              Code         3
# 40              Code         3
# 41              Code         3
# 42              Code         3
# 43              Code         3
# 44              Code         3
# 45              Code         3
# 46              Code         3
# 47              Code         3
# 48              Code         4
# 49              Code         4
# 50              Code         4
# 51              Code         4
# 52              Code         4
# 53              Code         5
# 54      LabTestEvent         2
# 55  DrugPrescription         2
#
#                                             relations  \
# 0                   hasCode,hasCodingSystemAndVersion
# 1                   hasCode,hasSubjectPseudIdentifier
# 2   hasCodingSystemAndVersion,hasSubjectPseudIdent...
# 3   hasCode,hasCodingSystemAndVersion,hasSubjectPs...
# 4   hasCodingSystemAndVersion⁻¹,hasCodingSystemAnd...
# 5   hasCodingSystemAndVersion⁻¹,hasCodingSystemAnd...
# 6   hasCodingSystemAndVersion⁻¹,hasCodingSystemAnd...
# 7   hasCodingSystemAndVersion⁻¹,hasCodingSystemAnd...
# 8   hasSubjectPseudIdentifier⁻¹,hasSubjectPseudIde...
# 9   hasSubjectPseudIdentifier⁻¹,hasSubjectPseudIde...
# 10  hasSubjectPseudIdentifier⁻¹,hasSubjectPseudIde...
# 11  hasSubjectPseudIdentifier⁻¹,hasSubjectPseudIde...
# 12  hasSubjectPseudIdentifier⁻¹,hasSubjectPseudIde...
# 13  hasSubjectPseudIdentifier⁻¹,hasSubjectPseudIde...
# 14  hasSubjectPseudIdentifier⁻¹,hasSubjectPseudIde...
# 15  hasSubjectPseudIdentifier⁻¹,hasSubjectPseudIde...
# 16  hasSubjectPseudIdentifier⁻¹,hasSubjectPseudIde...
# 17  hasSubjectPseudIdentifier⁻¹,hasSubjectPseudIde...
# 18  hasSubjectPseudIdentifier⁻¹,hasSubjectPseudIde...
# 19                  hasCode,hasCodingSystemAndVersion
# 20                  hasCode,hasSubjectPseudIdentifier
# 21  hasCodingSystemAndVersion,hasSubjectPseudIdent...
# 22  hasCode,hasCodingSystemAndVersion,hasSubjectPs...
# 23                               hasCode,hasLabTest⁻¹
# 24                        hasActiveIngredient,hasCode
# 25                      hasActiveIngredient,hasDrug⁻¹
# 26                                  hasCode,hasDrug⁻¹
# 27              hasActiveIngredient,hasCode,hasDrug⁻¹
# 28                hasCodingSystemAndVersion,hasCode⁻¹
# 29                hasCodingSystemAndVersion,hasCode⁻¹
# 30                hasCodingSystemAndVersion,hasCode⁻¹
# 31                hasCodingSystemAndVersion,hasCode⁻¹
# 32                                hasCode⁻¹,hasCode⁻¹
# 33                                hasCode⁻¹,hasCode⁻¹
# 34                                hasCode⁻¹,hasCode⁻¹
# 35                                hasCode⁻¹,hasCode⁻¹
# 36                                hasCode⁻¹,hasCode⁻¹
# 37                                hasCode⁻¹,hasCode⁻¹
# 38      hasCodingSystemAndVersion,hasCode⁻¹,hasCode⁻¹
# 39      hasCodingSystemAndVersion,hasCode⁻¹,hasCode⁻¹
# 40      hasCodingSystemAndVersion,hasCode⁻¹,hasCode⁻¹
# 41      hasCodingSystemAndVersion,hasCode⁻¹,hasCode⁻¹
# 42      hasCodingSystemAndVersion,hasCode⁻¹,hasCode⁻¹
# 43      hasCodingSystemAndVersion,hasCode⁻¹,hasCode⁻¹
# 44                      hasCode⁻¹,hasCode⁻¹,hasCode⁻¹
# 45                      hasCode⁻¹,hasCode⁻¹,hasCode⁻¹
# 46                      hasCode⁻¹,hasCode⁻¹,hasCode⁻¹
# 47                      hasCode⁻¹,hasCode⁻¹,hasCode⁻¹
# 48  hasCodingSystemAndVersion,hasCode⁻¹,hasCode⁻¹,...
# 49  hasCodingSystemAndVersion,hasCode⁻¹,hasCode⁻¹,...
# 50  hasCodingSystemAndVersion,hasCode⁻¹,hasCode⁻¹,...
# 51  hasCodingSystemAndVersion,hasCode⁻¹,hasCode⁻¹,...
# 52            hasCode⁻¹,hasCode⁻¹,hasCode⁻¹,hasCode⁻¹
# 53  hasCodingSystemAndVersion,hasCode⁻¹,hasCode⁻¹,...
# 54               hasLabTest,hasSubjectPseudIdentifier
# 55                  hasDrug,hasSubjectPseudIdentifier
#
#                                       target_entities  \
# 0                                   Code,CodingSystem
# 1                                        Code,Patient
# 2                                CodingSystem,Patient
# 3                           Code,CodingSystem,Patient
# 4                          Diagnosis,MedicalProcedure
# 5                                      Diagnosis,Code
# 6                               MedicalProcedure,Code
# 7                     Diagnosis,MedicalProcedure,Code
# 8                       LabTestEvent,MedicalProcedure
# 9                              LabTestEvent,Diagnosis
# 10                      LabTestEvent,DrugPrescription
# 11                         MedicalProcedure,Diagnosis
# 12                  MedicalProcedure,DrugPrescription
# 13                         Diagnosis,DrugPrescription
# 14            LabTestEvent,MedicalProcedure,Diagnosis
# 15     LabTestEvent,MedicalProcedure,DrugPrescription
# 16            LabTestEvent,Diagnosis,DrugPrescription
# 17        MedicalProcedure,Diagnosis,DrugPrescription
# 18  LabTestEvent,MedicalProcedure,Diagnosis,DrugPr...
# 19                                  Code,CodingSystem
# 20                                       Code,Patient
# 21                               CodingSystem,Patient
# 22                          Code,CodingSystem,Patient
# 23                                  Code,LabTestEvent
# 24                                     Substance,Code
# 25                         Substance,DrugPrescription
# 26                              Code,DrugPrescription
# 27                    Substance,Code,DrugPrescription
# 28                             CodingSystem,LabResult
# 29                                  CodingSystem,Drug
# 30                      CodingSystem,MedicalProcedure
# 31                             CodingSystem,Diagnosis
# 32                                     LabResult,Drug
# 33                         LabResult,MedicalProcedure
# 34                                LabResult,Diagnosis
# 35                              Drug,MedicalProcedure
# 36                                     Drug,Diagnosis
# 37                         MedicalProcedure,Diagnosis
# 38                        CodingSystem,LabResult,Drug
# 39            CodingSystem,LabResult,MedicalProcedure
# 40                   CodingSystem,LabResult,Diagnosis
# 41                 CodingSystem,Drug,MedicalProcedure
# 42                        CodingSystem,Drug,Diagnosis
# 43            CodingSystem,MedicalProcedure,Diagnosis
# 44                    LabResult,Drug,MedicalProcedure
# 45                           LabResult,Drug,Diagnosis
# 46               LabResult,MedicalProcedure,Diagnosis
# 47                    Drug,MedicalProcedure,Diagnosis
# 48       CodingSystem,LabResult,Drug,MedicalProcedure
# 49              CodingSystem,LabResult,Drug,Diagnosis
# 50  CodingSystem,LabResult,MedicalProcedure,Diagnosis
# 51       CodingSystem,Drug,MedicalProcedure,Diagnosis
# 52          LabResult,Drug,MedicalProcedure,Diagnosis
# 53  CodingSystem,LabResult,Drug,MedicalProcedure,D...
# 54                                  LabResult,Patient
# 55                                       Drug,Patient
#
#                                   star_representation  \
# 0   Diagnosis--hasCode--> Code,Diagnosis--hasCodin...
# 1   Diagnosis--hasCode--> Code,Diagnosis--hasSubje...
# 2   Diagnosis--hasCodingSystemAndVersion--> Coding...
# 3   Diagnosis--hasCode--> Code,Diagnosis--hasCodin...
# 4   CodingSystem--hasCodingSystemAndVersion⁻¹--> D...
# 5   CodingSystem--hasCodingSystemAndVersion⁻¹--> D...
# 6   CodingSystem--hasCodingSystemAndVersion⁻¹--> M...
# 7   CodingSystem--hasCodingSystemAndVersion⁻¹--> D...
# 8   Patient--hasSubjectPseudIdentifier⁻¹--> LabTes...
# 9   Patient--hasSubjectPseudIdentifier⁻¹--> LabTes...
# 10  Patient--hasSubjectPseudIdentifier⁻¹--> LabTes...
# 11  Patient--hasSubjectPseudIdentifier⁻¹--> Medica...
# 12  Patient--hasSubjectPseudIdentifier⁻¹--> Medica...
# 13  Patient--hasSubjectPseudIdentifier⁻¹--> Diagno...
# 14  Patient--hasSubjectPseudIdentifier⁻¹--> LabTes...
# 15  Patient--hasSubjectPseudIdentifier⁻¹--> LabTes...
# 16  Patient--hasSubjectPseudIdentifier⁻¹--> LabTes...
# 17  Patient--hasSubjectPseudIdentifier⁻¹--> Medica...
# 18  Patient--hasSubjectPseudIdentifier⁻¹--> LabTes...
# 19  MedicalProcedure--hasCode--> Code,MedicalProce...
# 20  MedicalProcedure--hasCode--> Code,MedicalProce...
# 21  MedicalProcedure--hasCodingSystemAndVersion-->...
# 22  MedicalProcedure--hasCode--> Code,MedicalProce...
# 23  LabResult--hasCode--> Code,LabResult--hasLabTe...
# 24  Drug--hasActiveIngredient--> Substance,Drug--h...
# 25  Drug--hasActiveIngredient--> Substance,Drug--h...
# 26  Drug--hasCode--> Code,Drug--hasDrug⁻¹--> DrugP...
# 27  Drug--hasActiveIngredient--> Substance,Drug--h...
# 28  Code--hasCodingSystemAndVersion--> CodingSyste...
# 29  Code--hasCodingSystemAndVersion--> CodingSyste...
# 30  Code--hasCodingSystemAndVersion--> CodingSyste...
# 31  Code--hasCodingSystemAndVersion--> CodingSyste...
# 32  Code--hasCode⁻¹--> LabResult,Code--hasCode⁻¹--...
# 33  Code--hasCode⁻¹--> LabResult,Code--hasCode⁻¹--...
# 34  Code--hasCode⁻¹--> LabResult,Code--hasCode⁻¹--...
# 35  Code--hasCode⁻¹--> Drug,Code--hasCode⁻¹--> Med...
# 36  Code--hasCode⁻¹--> Drug,Code--hasCode⁻¹--> Dia...
# 37  Code--hasCode⁻¹--> MedicalProcedure,Code--hasC...
# 38  Code--hasCodingSystemAndVersion--> CodingSyste...
# 39  Code--hasCodingSystemAndVersion--> CodingSyste...
# 40  Code--hasCodingSystemAndVersion--> CodingSyste...
# 41  Code--hasCodingSystemAndVersion--> CodingSyste...
# 42  Code--hasCodingSystemAndVersion--> CodingSyste...
# 43  Code--hasCodingSystemAndVersion--> CodingSyste...
# 44  Code--hasCode⁻¹--> LabResult,Code--hasCode⁻¹--...
# 45  Code--hasCode⁻¹--> LabResult,Code--hasCode⁻¹--...
# 46  Code--hasCode⁻¹--> LabResult,Code--hasCode⁻¹--...
# 47  Code--hasCode⁻¹--> Drug,Code--hasCode⁻¹--> Med...
# 48  Code--hasCodingSystemAndVersion--> CodingSyste...
# 49  Code--hasCodingSystemAndVersion--> CodingSyste...
# 50  Code--hasCodingSystemAndVersion--> CodingSyste...
# 51  Code--hasCodingSystemAndVersion--> CodingSyste...
# 52  Code--hasCode⁻¹--> LabResult,Code--hasCode⁻¹--...
# 53  Code--hasCodingSystemAndVersion--> CodingSyste...
# 54  LabTestEvent--hasLabTest--> LabResult,LabTestE...
# 55  DrugPrescription--hasDrug--> Drug,DrugPrescrip...
#
#                                           arms_tuples
# 0   [('hasCode', 'Code'), ('hasCodingSystemAndVers...
# 1   [('hasCode', 'Code'), ('hasSubjectPseudIdentif...
# 2   [('hasCodingSystemAndVersion', 'CodingSystem')...
# 3   [('hasCode', 'Code'), ('hasCodingSystemAndVers...
# 4   [('hasCodingSystemAndVersion⁻¹', 'Diagnosis'),...
# 5   [('hasCodingSystemAndVersion⁻¹', 'Diagnosis'),...
# 6   [('hasCodingSystemAndVersion⁻¹', 'MedicalProce...
# 7   [('hasCodingSystemAndVersion⁻¹', 'Diagnosis'),...
# 8   [('hasSubjectPseudIdentifier⁻¹', 'LabTestEvent...
# 9   [('hasSubjectPseudIdentifier⁻¹', 'LabTestEvent...
# 10  [('hasSubjectPseudIdentifier⁻¹', 'LabTestEvent...
# 11  [('hasSubjectPseudIdentifier⁻¹', 'MedicalProce...
# 12  [('hasSubjectPseudIdentifier⁻¹', 'MedicalProce...
# 13  [('hasSubjectPseudIdentifier⁻¹', 'Diagnosis'),...
# 14  [('hasSubjectPseudIdentifier⁻¹', 'LabTestEvent...
# 15  [('hasSubjectPseudIdentifier⁻¹', 'LabTestEvent...
# 16  [('hasSubjectPseudIdentifier⁻¹', 'LabTestEvent...
# 17  [('hasSubjectPseudIdentifier⁻¹', 'MedicalProce...
# 18  [('hasSubjectPseudIdentifier⁻¹', 'LabTestEvent...
# 19  [('hasCode', 'Code'), ('hasCodingSystemAndVers...
# 20  [('hasCode', 'Code'), ('hasSubjectPseudIdentif...
# 21  [('hasCodingSystemAndVersion', 'CodingSystem')...
# 22  [('hasCode', 'Code'), ('hasCodingSystemAndVers...
# 23  [('hasCode', 'Code'), ('hasLabTest⁻¹', 'LabTes...
# 24  [('hasActiveIngredient', 'Substance'), ('hasCo...
# 25  [('hasActiveIngredient', 'Substance'), ('hasDr...
# 26  [('hasCode', 'Code'), ('hasDrug⁻¹', 'DrugPresc...
# 27  [('hasActiveIngredient', 'Substance'), ('hasCo...
# 28  [('hasCodingSystemAndVersion', 'CodingSystem')...
# 29  [('hasCodingSystemAndVersion', 'CodingSystem')...
# 30  [('hasCodingSystemAndVersion', 'CodingSystem')...
# 31  [('hasCodingSystemAndVersion', 'CodingSystem')...
# 32  [('hasCode⁻¹', 'LabResult'), ('hasCode⁻¹', 'Dr...
# 33  [('hasCode⁻¹', 'LabResult'), ('hasCode⁻¹', 'Me...
# 34  [('hasCode⁻¹', 'LabResult'), ('hasCode⁻¹', 'Di...
# 35  [('hasCode⁻¹', 'Drug'), ('hasCode⁻¹', 'Medical...
# 36  [('hasCode⁻¹', 'Drug'), ('hasCode⁻¹', 'Diagnos...
# 37  [('hasCode⁻¹', 'MedicalProcedure'), ('hasCode⁻...
# 38  [('hasCodingSystemAndVersion', 'CodingSystem')...
# 39  [('hasCodingSystemAndVersion', 'CodingSystem')...
# 40  [('hasCodingSystemAndVersion', 'CodingSystem')...
# 41  [('hasCodingSystemAndVersion', 'CodingSystem')...
# 42  [('hasCodingSystemAndVersion', 'CodingSystem')...
# 43  [('hasCodingSystemAndVersion', 'CodingSystem')...
# 44  [('hasCode⁻¹', 'LabResult'), ('hasCode⁻¹', 'Dr...
# 45  [('hasCode⁻¹', 'LabResult'), ('hasCode⁻¹', 'Dr...
# 46  [('hasCode⁻¹', 'LabResult'), ('hasCode⁻¹', 'Me...
# 47  [('hasCode⁻¹', 'Drug'), ('hasCode⁻¹', 'Medical...
# 48  [('hasCodingSystemAndVersion', 'CodingSystem')...
# 49  [('hasCodingSystemAndVersion', 'CodingSystem')...
# 50  [('hasCodingSystemAndVersion', 'CodingSystem')...
# 51  [('hasCodingSystemAndVersion', 'CodingSystem')...
# 52  [('hasCode⁻¹', 'LabResult'), ('hasCode⁻¹', 'Dr...
# 53  [('hasCodingSystemAndVersion', 'CodingSystem')...
# 54  [('hasLabTest', 'LabResult'), ('hasSubjectPseu...
# 55  [('hasDrug', 'Drug'), ('hasSubjectPseudIdentif...

# %%
def generate_sparql_from_star_query(arms_tuples_str, center_variable="?center"):
    """
    Generate SPARQL query from star query arms tuples
    Args:
        arms_tuples_str: String representation of arms tuples from DataFrame
        center_variable: Variable name for the center entity (default: "?center")
    """
    import ast
    
    # Parse the string representation back to list of tuples
    try:
        arms = ast.literal_eval(arms_tuples_str)
    except:
        return "Error: Could not parse arms tuples"
    
    # Start building SPARQL query
    sparql_lines = ["SELECT DISTINCT * WHERE {"]
    
    # Add triple patterns for each arm
    for i, (relation, target_entity) in enumerate(arms):
        target_var = f"?{target_entity.lower()}{i+1}"
        
        # Handle inverse relations (those ending with ⁻¹)
        if relation.endswith('⁻¹'):
            # Inverse relation: target relates to center
            clean_relation = relation[:-1]  # Remove ⁻¹
            sparql_lines.append(f"  {target_var} <{clean_relation}> {center_variable} .")
        else:
            # Regular relation: center relates to target
            sparql_lines.append(f"  {center_variable} <{relation}> {target_var} .")
    
    sparql_lines.append("}")
    
    return "\n".join(sparql_lines)


def generate_sparql_from_chain_query(query_tuples_str):
    """
    Generate SPARQL query from chain query tuples
    Args:
        query_tuples_str: String representation of query tuples from DataFrame
    """
    import ast
    
    # Parse the string representation back to list of tuples
    try:
        chain = ast.literal_eval(query_tuples_str)
    except:
        return "Error: Could not parse query tuples"
    
    if not chain:
        return "Error: Empty chain query"
    
    # Start building SPARQL query
    sparql_lines = ["SELECT DISTINCT * WHERE {"]
    
    # Keep track of variables used
    variables = {}
    var_counter = 0
    
    # Process each hop in the chain
    for i, (source_entity, relation, target_entity) in enumerate(chain):
        # Get or create variable for source
        if source_entity not in variables:
            variables[source_entity] = f"?{source_entity.lower()}{var_counter}"
            var_counter += 1
        source_var = variables[source_entity]
        
        # Get or create variable for target
        if target_entity not in variables:
            variables[target_entity] = f"?{target_entity.lower()}{var_counter}"
            var_counter += 1
        target_var = variables[target_entity]
        
        # Handle inverse relations (those ending with ⁻¹)
        if relation.endswith('⁻¹'):
            # Inverse relation: target relates to source
            clean_relation = relation[:-1]  # Remove ⁻¹
            sparql_lines.append(f"  {target_var} <{clean_relation}> {source_var} .")
        else:
            # Regular relation: source relates to target
            sparql_lines.append(f"  {source_var} <{relation}> {target_var} .")
    
    sparql_lines.append("}")
    
    return "\n".join(sparql_lines)

# %%
generate_sparql_from_chain_query(chain_df['query_tuples'][900])
# Out:
# 'SELECT DISTINCT * WHERE {\n  ?labresult0 <hasCode> ?code1 .\n  ?code1 <hasCodingSystemAndVersion> ?codingsystem2 .\n  ?diagnosis3 <hasCodingSystemAndVersion⁻> ?codingsystem2 .\n  ?diagnosis3 <hasCodingSystemAndVersion> ?codingsystem2 .\n}'
